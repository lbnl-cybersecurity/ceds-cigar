# %%
local = {
    'worker_1': {
        'grad_time_ms': 200.911,
        'sample_time_ms': 21844.924,
        'update_time_ms': 281.69,
        'mean_env_wait_ms': 1005.8692027744378,
        'mean_inference_ms': 4.300671587422334,
        'mean_processing_ms': 53.60668683024372,
        'time_this_iter_s': 23.431466341018677,
    },
    'worker_2': {
        'grad_time_ms': 177.804,
        'sample_time_ms': 24615.642,
        'update_time_ms': 212.288,
        'mean_env_wait_ms': 1140.2578261828535,
        'mean_inference_ms': 1.8897870661547895,
        'mean_processing_ms': 63.69309355809009,
        'time_this_iter_s': 26.345250368118286,
    },
    'worker_4': {
        'grad_time_ms': 167.934,
        'sample_time_ms': 29546.078,
        'update_time_ms': 160.303,
        'mean_env_wait_ms': 1334.4355671755243,
        'mean_inference_ms': 2.2232539731935494,
        'mean_processing_ms': 78.34545836635927,
        'time_this_iter_s': 34.035473585128784,
    },
    'worker_6': {
        'grad_time_ms': 281.409,
        'sample_time_ms': 37092.518,
        'update_time_ms': 327.7,
        'mean_env_wait_ms': 1698.2469012282218,
        'mean_inference_ms': 3.2398377192191177,
        'mean_processing_ms': 84.24818331171643,
        'time_this_iter_s': 40.391759395599365,
    },
    'worker_8': {
        'grad_time_ms': 358.473,
        'sample_time_ms': 47484.018,
        'update_time_ms': 336.835,
        'mean_env_wait_ms': 2145.736553839275,
        'mean_inference_ms': 3.4657035382090267,
        'mean_processing_ms': 105.45550757515028,
        'time_this_iter_s': 52.37924385070801,
    }
}

gig = {
    'worker_1': {
        'grad_time_ms': 292.426,
        'sample_time_ms': 26198.1,
        'update_time_ms': 466.249,
        'mean_env_wait_ms': 1237.675555630151,
        'mean_inference_ms': 2.5141124249058455,
        'mean_processing_ms': 61.99769912834921,
        'time_this_iter_s': 26.981128931045532,
    },
    'worker_2': {
        'grad_time_ms': 295.14,
        'sample_time_ms': 31048.924,
        'update_time_ms': 377.051,
        'mean_env_wait_ms': 1360.048233839693,
        'mean_inference_ms': 2.862548163543595,
        'mean_processing_ms': 74.16480571966137,
        'time_this_iter_s': 33.55190086364746,
    },
    'worker_4': {
        'grad_time_ms': 363.724,
        'sample_time_ms': 28992.585,
        'update_time_ms': 343.997,
        'mean_env_wait_ms': 1257.2060568684346,
        'mean_inference_ms': 2.77959988923023,
        'mean_processing_ms': 67.98451837762308,
        'time_this_iter_s': 32.656267404556274,
    },
    'worker_6': {
        'grad_time_ms': 484.875,
        'sample_time_ms': 28478.8,
        'update_time_ms': 326.0,
        'mean_env_wait_ms': 1249.0446220476222,
        'mean_inference_ms': 2.6258965171772615,
        'mean_processing_ms': 68.42433725546093,
        'time_this_iter_s': 33.03834509849548,
    },
    'worker_8': {
        'grad_time_ms': 611.708,
        'sample_time_ms': 31593.995,
        'update_time_ms': 421.604,
        'mean_env_wait_ms': 1328.556615716489,
        'mean_inference_ms': 2.710165445120631,
        'mean_processing_ms': 69.67551298396236,
        'time_this_iter_s': 37.516716957092285,
    },
    'worker_10': {
        'grad_time_ms': 598.861,
        'sample_time_ms': 35193.451,
        'update_time_ms': 320.64,
        'mean_env_wait_ms': 1556.4153521180015,
        'mean_inference_ms': 3.2405497858887076,
        'mean_processing_ms': 74.7004335350276,
        'time_this_iter_s': 41.44006109237671,
    },
    'worker_12': {
        'grad_time_ms': 635.118,
        'sample_time_ms': 42293.196,
        'update_time_ms': 205.999,
        'mean_env_wait_ms': 1853.520962716495,
        'mean_inference_ms': 2.974431733704835,
        'mean_processing_ms': 79.65743975301919,
        'time_this_iter_s': 49.436362504959106,
    },
    'worker_14': {
        'grad_time_ms': 776.719,
        'sample_time_ms': 46106.439,
        'update_time_ms': 260.259,
        'mean_env_wait_ms': 2106.3763464263184,
        'mean_inference_ms': 3.2897681604113673,
        'mean_processing_ms': 97.11787546031546,
        'time_this_iter_s': 54.39741921424866,
    }
}

lr6 = {
    'worker_1': {
        'grad_time_ms': 193.846,
        'sample_time_ms': 33367.888,
        'update_time_ms': 215.554,
        'mean_env_wait_ms': 1561.5891616593806,
        'mean_inference_ms': 2.8518164918156423,
        'mean_processing_ms': 88.84194779678869,
        'time_this_iter_s': 35.707825899124146,
    },
    'worker_2': {
        'grad_time_ms': 245.115,
        'sample_time_ms': 32911.972,
        'update_time_ms': 226.544,
        'mean_env_wait_ms': 1510.0952110612955,
        'mean_inference_ms': 3.18628228520342,
        'mean_processing_ms': 85.2532727680388,
        'time_this_iter_s': 36.67139267921448,
    },
    'worker_4': {
        'grad_time_ms': 555.349,
        'sample_time_ms': 33511.379,
        'update_time_ms': 207.503,
        'mean_env_wait_ms': 1496.0226550287177,
        'mean_inference_ms': 5.335363694374235,
        'mean_processing_ms': 85.34214470593703,
        'time_this_iter_s': 38.11227083206177,
    },
    'worker_6': {
        'grad_time_ms': 452.237,
        'sample_time_ms': 33931.339,
        'update_time_ms': 218.841,
        'mean_env_wait_ms': 1510.9196992870325,
        'mean_inference_ms': 3.2588439598051298,
        'mean_processing_ms': 85.06985702637598,
        'time_this_iter_s': 38.91789197921753,
    },
    'worker_8': {
        'grad_time_ms': 542.317,
        'sample_time_ms': 33421.223,
        'update_time_ms': 222.572,
        'mean_env_wait_ms': 1497.587206066334,
        'mean_inference_ms':3.26484239674218,
        'mean_processing_ms': 84.424420020689,
        'time_this_iter_s': 39.47864007949829,
    },
    'worker_10': {
        'grad_time_ms': 953.399,
        'sample_time_ms': 26557.233,
        'update_time_ms': 204.272,
        'mean_env_wait_ms': 1179.5590199454136,
        'mean_inference_ms': 12.886175468912912,
        'mean_processing_ms': 70.30062065308029,
        'time_this_iter_s': 31.64210319519043,
    },
    'worker_12': {
        'grad_time_ms': 644.432,
        'sample_time_ms': 26962.971,
        'update_time_ms': 193.204,
        'mean_env_wait_ms': 1184.0636614319817,
        'mean_inference_ms': 2.9941632013972654,
        'mean_processing_ms': 70.20790020433634,
        'time_this_iter_s': 33.664016008377075,
    },
    'worker_14': {
        'grad_time_ms': 720.741,
        'sample_time_ms': 27200.867,
        'update_time_ms': 216.561,
        'mean_env_wait_ms': 1193.946884104329,
        'mean_inference_ms': 2.7539293913453573,
        'mean_processing_ms': 70.35823189563675,
        'time_this_iter_s': 34.54695773124695,
    },
    'worker_18': {
        'grad_time_ms': 829.988,
        'sample_time_ms': 27350.961,
        'update_time_ms': 227.42,
        'mean_env_wait_ms': 1204.5597047195652,
        'mean_inference_ms': 2.8488342588384796,
        'mean_processing_ms': 71.57476564298882,
        'time_this_iter_s': 36.222097873687744,
    },
    'worker_22': {
        'grad_time_ms': 1085.89,
        'sample_time_ms': 27339.036,
        'update_time_ms': 225.194,
        'mean_env_wait_ms': 1207.2474081947973,
        'mean_inference_ms': 2.7852969230520155,
        'mean_processing_ms': 73.0798569428178,
        'time_this_iter_s': 39.806678771972656,
    },
    'worker_26': {
        'grad_time_ms': 1083.073,
        'sample_time_ms': 27323.759,
        'update_time_ms': 236.343,
        'mean_env_wait_ms': 1210.0073652191204,
        'mean_inference_ms': 2.809039236200397,
        'mean_processing_ms': 73.50533880311254,
        'time_this_iter_s': 41.6199004650116,
    },
    'worker_30': {
        'grad_time_ms': 1345.625,
        'sample_time_ms': 27458.341,
        'update_time_ms': 239.015,
        'mean_env_wait_ms': 1213.7220861397354,
        'mean_inference_ms': 2.8479123455043,
        'mean_processing_ms': 74.11064474503014,
        'time_this_iter_s': 42.66653037071228,
    },
}

# %%
local_no_worker = {'total_step_s': 10.045363664627075, 'mean_step_s': 0.5022684454917907}
gig_no_worker = {'total_step_s': 12.537657499313354, 'mean_step_s': 0.626883351802826}
lr6_no_worker = {'total_step_s': 11.551141500473022, 'mean_step_s': 0.5775572180747985}

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(20,15))
tittle = 'sample_time_ms'
plt.title(tittle)
plt.xlabel('number workers')
plt.ylabel('second' if tittle[-2:] == '_s' else 'milisecond')
plt.plot([int(key[7:]) for key in local.keys()], [local[key][tittle] for key in local.keys()], label='Local')
plt.scatter([int(key[7:]) for key in local.keys()], [local[key][tittle] for key in local.keys()])
plt.plot([int(key[7:]) for key in gig.keys()], [gig[key][tittle] for key in gig.keys()], label='GIG Server')
plt.scatter([int(key[7:]) for key in gig.keys()], [gig[key][tittle] for key in gig.keys()])
plt.plot([int(key[7:]) for key in lr6.keys()], [lr6[key][tittle] for key in lr6.keys()], label='lr6 32-cpu')
plt.scatter([int(key[7:]) for key in lr6.keys()], [lr6[key][tittle] for key in lr6.keys()])

if tittle == 'time_this_iter_s':
    plt.hlines(local_no_worker['total_step_s'], 0, 30, linestyles='--', color='C0', label='Local (simulation only)')
    plt.hlines(gig_no_worker['total_step_s'], 0, 30, linestyles='--', color='C1', label='GIG Server (simulation only)')
    plt.hlines(lr6_no_worker['total_step_s'], 0, 30, linestyles='--', color='C2', label='lr6 32-cpu (simulation only)')

if tittle == 'mean_env_wait_ms':
    plt.hlines(local_no_worker['mean_step_s']*1000, 0, 30, linestyles='--', color='C0', label='Local (simulation only)')
    plt.hlines(gig_no_worker['mean_step_s']*1000, 0, 30, linestyles='--', color='C1', label='GIG Server (simulation only)')
    plt.hlines(lr6_no_worker['mean_step_s']*1000, 0, 30, linestyles='--', color='C2', label='lr6 32-cpu (simulation only)')
plt.legend(loc=1)
plt.show()

# %%
time = {"init env":  4.38690185546875e-05,
"rest env":  0.8054461479187012,
"step env":  0.32890459299087527,
"ttal env":  7.383594274520874,
"odss env":  0.6544070243835449,
"scen env":  0.5108788013458252,
"node env":  0.22127008438110352,
"devi env":  6.16039514541626,
"simu env":  0.05093884468078613,
"ctrl env":  0.055150508880615234,
"desp env":  6.0229902267456055
}

time_butter = {'init env':  5.91278076171875e-05,
"rest env":  1.1920480728149414,
"step env":  0.4909963011741638,
"ttal env":  11.01204514503479,
"odss env":  0.748399019241333,
"scen env":  0.5771410465240479,
"node env":  0.2581305503845215,
"devi env":  9.482036113739014,
"simu env":  0.05760693550109863,
"ctrl env":  0.06950712203979492,
"desp env":  9.312484502792358,
}

# %%
time = {"init env":  4.38690185546875e-05,
"rest env":  0.8054461479187012,
"step env":  0.32890459299087527,
"ttal env":  7.383594274520874,
"odss env":  0.6544070243835449,
"scen env":  0.5108788013458252,
"node env":  0.22127008438110352,
"devi env":  6.16039514541626,
"simu env":  0.05093884468078613,
"ctrl env":  0.055150508880615234,
"desp env":  6.0229902267456055
}

time_butter = {'init env':  5.91278076171875e-05,
"rest env":  1.1920480728149414,
"step env":  0.4909963011741638,
"ttal env":  11.01204514503479,
"odss env":  0.748399019241333,
"scen env":  0.5771410465240479,
"node env":  0.2581305503845215,
"devi env":  9.482036113739014,
"simu env":  0.05760693550109863,
"ctrl env":  0.06950712203979492,
"desp env":  9.312484502792358,
}

time_after_improve_butter = {
"init env":  4.553794860839844e-05,
"rest env":  0.7902390956878662,
"step env":  0.29412590265274047,
"ttal env":  6.672815322875977,
"odss env":  0.680279016494751,
"scen env":  0.5453119277954102,
"node env":  0.27970409393310547,
"devi env":  5.236025094985962,
"simu env":  0.04473876953125,
"ctrl env":  0.062282562255859375,
"desp env":  5.116685628890991
}

time_after_improve = {
"init env":  4.9591064453125e-05,
"rest env":  0.6721022129058838,
"step env":  0.22433210611343385,
"ttal env":  5.158803462982178,
"odss env":  0.7151427268981934,
"scen env":  0.5572195053100586,
"node env":  0.2491762638092041,
"devi env":  3.7928831577301025,
"simu env":  0.05605506896972656,
"ctrl env":  0.06805109977722168,
"desp env":  3.6653189659118652,
}
time_after_improve = {
"init env":  4.506111145019531e-05,
"rest env":  0.5781834125518799,
"step env":  0.18630436658859253,
"ttal env":  4.3043248653411865,
"odss env":  0.6193768978118896,
"scen env":  0.49010705947875977,
"node env":  0.2109668254852295,
"devi env":  3.137312412261963,
"simu env":  0.04193282127380371,
"ctrl env":  0.05473828315734863,
"desp env":  3.0257089138031006,
}

time_after_improve = {
"init env":  4.267692565917969e-05,
"rest env":  0.5188202857971191,
"step env":  0.1822611927986145,
"ttal env":  4.164098501205444,
"odss env":  0.6122391223907471,
"scen env":  0.4983096122741699,
"node env":  0.24327945709228516,
"devi env":  2.960989475250244,
"simu env":  0.03896141052246094,
"ctrl env":  0.05302786827087402,
"desp env":  2.8597474098205566,
}

time_after_improve = {
"init env":  4.410743713378906e-05,
"rest env":  0.5309598445892334,
"step env":  0.1819644570350647,
"ttal env":  4.1703033447265625,
"odss env":  0.620969295501709,
"scen env":  0.5033903121948242,
"node env":  0.24982857704162598,
"devi env":  2.946287155151367,
"simu env":  0.0396878719329834,
"ctrl env":  0.05424022674560547,
"desp env":  2.841789960861206,
}

time_after_improve = {
"init env":  4.5299530029296875e-05,
"rest env":  0.5203962326049805,
"step env":  0.17498083114624025,
"ttal env":  4.020067930221558,
"odss env":  0.6302940845489502,
"scen env":  0.5135977268218994,
"node env":  0.25389790534973145,
"devi env":  2.7752246856689453,
"simu env":  0.03902840614318848,
"ctrl env":  0.0565488338470459,
"desp env":  2.6716177463531494,
}

time_after_improve = {
"init env":  8.153915405273438e-05,
"rest env":  0.5141441822052002,
"step env":  0.16267653703689575,
"ttal env":  3.7677717208862305,
"odss env":  0.5866646766662598,
"scen env":  0.47211146354675293,
"node env":  0.23819875717163086,
"devi env":  2.5834031105041504,
"simu env":  0.037944793701171875,
"ctrl env":  0.05306673049926758,
"desp env":  2.485764741897583
}

# %%
import pandas as pd

def making_df(d):
    df = pd.DataFrame(dict(
        init_env= [d['init env'], 0, 0],
        reset_env=[d['rest env']+d['init env'], 0, 0],
        odss_call=[d['rest env']+d['init env'] + d['odss env'], 0, 0], 
        other=    [d['ttal env'], 0, 0],
        
        kernel_update_scen=[0, d['scen env']+d['simu env']+d['node env'], 0],
        kernel_update_node=[0, d['node env']+d['simu env'], 0],
        kernel_update_devi=[0, d['scen env']+d['node env']+d['devi env']+d['simu env'], 0],
        kernel_update_simu=[0, d['simu env'], 0],
        device_update=[0, d['desp env']+d['scen env']+d['node env']+d['simu env'], 0]

        ))

    return df

import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20, 10))
plt.grid()
df = making_df(time)
old_filter = [plt.bar([0, 1, 2], df.other, align='edge', edgecolor='black', width= 0.2, color='grey',label='other'),
               plt.bar([0, 1, 2], df.odss_call, align='edge', edgecolor='black', width= 0.2, label='opendss call',  color='#1f77b4'),
               plt.bar([0, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2, label='reset environment',  color='#ff7f0e'),
               plt.bar([0, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2, label='initialize environment',  color='#2ca02c'),
               
               plt.bar([0, 1, 2], df.kernel_update_devi, align='edge', edgecolor='black', width= 0.2, label='kernel device',  color="#bcbd22"),
               plt.bar([0, 1, 2], df.device_update, align='edge', edgecolor='black', width= 0.2, label='only device',  color="#bcbd22", hatch="/"),
               plt.bar([0, 1, 2], df.kernel_update_scen, align='edge', edgecolor='black', width= 0.2, label='kernel scenario',  color="#9467bd"),
               plt.bar([0, 1, 2], df.kernel_update_node, align='edge', edgecolor='black', width= 0.2, label='kernel node',  color="#8c564b"),
               plt.bar([0, 1, 2], df.kernel_update_simu, align='edge', edgecolor='black', width= 0.2, label='kernel simulation',  color="#e377c2"),
               ]

plt.text(x=0.05, y=(df.other[0]+0.1)/2 , s="{:4.2f} s".format(df.other[0]) , fontdict=dict(fontsize=15))
plt.text(x=0.02, y=df.other[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.other[0]-df.odss_call[0], (1-df.odss_call[0]/df.other[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=0.02, y=df.odss_call[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.odss_call[0]-df.reset_env[0], ((df.odss_call[0]-df.reset_env[0])/df.other[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=0.02, y=df.reset_env[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.other[0])*100) , fontdict=dict(fontsize=10))

plt.text(x=1.04, y=(df.kernel_update_devi[1]+0.1)/2 , s="{:4.2f} s".format(df.kernel_update_devi[1]) , fontdict=dict(fontsize=15))
plt.text(x=1.02, y=df.kernel_update_devi[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_devi[1]-df.kernel_update_scen[1], (df.kernel_update_devi[1]-df.kernel_update_scen[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))
plt.text(x=1.02, y=df.kernel_update_scen[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_scen[1]-df.kernel_update_node[1], (df.kernel_update_scen[1]-df.kernel_update_node[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))
plt.text(x=1.02, y=df.kernel_update_node[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_node[1]-df.kernel_update_simu[1], (df.kernel_update_node[1]-df.kernel_update_simu[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))

df = making_df(time_butter)
butter_filter = [plt.bar([0-0.2, 1, 2], df.other, align='edge', edgecolor='black', width= 0.2,  color='grey'),
               plt.bar([0-0.2, 1, 2], df.odss_call, align='edge', edgecolor='black', width= 0.2, color='#1f77b4'),
               plt.bar([0-0.2, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2,  color='#ff7f0e'),
               plt.bar([0-0.2, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2,  color='#2ca02c'),
               
               plt.bar([0, 1-0.2, 2], df.kernel_update_devi, align='edge', edgecolor='black', width= 0.2,  color="#bcbd22"),
               plt.bar([0, 1-0.2, 2], df.device_update, align='edge', edgecolor='black', width= 0.2, color="#bcbd22", hatch="/"),
               plt.bar([0, 1-0.2, 2], df.kernel_update_scen, align='edge', edgecolor='black', width= 0.2,  color="#9467bd"),
               plt.bar([0, 1-0.2, 2], df.kernel_update_node, align='edge', edgecolor='black', width= 0.2,  color="#8c564b"),
               plt.bar([0, 1-0.2, 2], df.kernel_update_simu, align='edge', edgecolor='black', width= 0.2,  color="#e377c2"),
               ]

plt.text(x=-0.16, y=(df.other[0]+0.1)/2 , s="{:4.2f} s".format(df.other[0]) , fontdict=dict(fontsize=15))

plt.text(x=-0.18, y=df.other[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.other[0]-df.odss_call[0], (1-df.odss_call[0]/df.other[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=-0.18, y=df.odss_call[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.odss_call[0]-df.reset_env[0], ((df.odss_call[0]-df.reset_env[0])/df.other[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=-0.18, y=df.reset_env[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.other[0])*100) , fontdict=dict(fontsize=10))

plt.text(x=0.84, y=(df.kernel_update_devi[1]+0.1)/2 , s="{:4.2f} s".format(df.kernel_update_devi[1]) , fontdict=dict(fontsize=15))
plt.text(x=0.82, y=df.kernel_update_devi[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_devi[1]-df.kernel_update_scen[1], (df.kernel_update_devi[1]-df.kernel_update_scen[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))
plt.text(x=0.82, y=df.kernel_update_scen[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_scen[1]-df.kernel_update_node[1], (df.kernel_update_scen[1]-df.kernel_update_node[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))
plt.text(x=0.82, y=df.kernel_update_node[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_node[1]-df.kernel_update_simu[1], (df.kernel_update_node[1]-df.kernel_update_simu[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))
################################################

df = making_df(time_after_improve)
butter_filter = [plt.bar([0+0.2, 1, 2], df.other, align='edge', edgecolor='black', width= 0.2,  color='grey'),
               plt.bar([0+0.2, 1, 2], df.odss_call, align='edge', edgecolor='black', width= 0.2, color='#1f77b4'),
               plt.bar([0+0.2, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2,  color='#ff7f0e'),
               plt.bar([0+0.2, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2,  color='#2ca02c'),
               
               plt.bar([0, 1+0.2, 2], df.kernel_update_devi, align='edge', edgecolor='black', width= 0.2,  color="#bcbd22"),
               plt.bar([0, 1+0.2, 2], df.device_update, align='edge', edgecolor='black', width= 0.2, color="#bcbd22", hatch="/"),
               plt.bar([0, 1+0.2, 2], df.kernel_update_scen, align='edge', edgecolor='black', width= 0.2,  color="#9467bd"),
               plt.bar([0, 1+0.2, 2], df.kernel_update_node, align='edge', edgecolor='black', width= 0.2,  color="#8c564b"),
               plt.bar([0, 1+0.2, 2], df.kernel_update_simu, align='edge', edgecolor='black', width= 0.2,  color="#e377c2"),
               ]

plt.text(x=0.24, y=(df.other[0]+0.1)/2 , s="{:4.2f} s".format(df.other[0]) , fontdict=dict(fontsize=15))

plt.text(x=0.21, y=df.other[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.other[0]-df.odss_call[0], (1-df.odss_call[0]/df.other[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=0.21, y=df.odss_call[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.odss_call[0]-df.reset_env[0], ((df.odss_call[0]-df.reset_env[0])/df.other[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=0.21, y=df.reset_env[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.other[0])*100) , fontdict=dict(fontsize=10))

plt.text(x=1.24, y=(df.kernel_update_devi[1]+0.1)/2 , s="{:4.2f} s".format(df.kernel_update_devi[1]) , fontdict=dict(fontsize=15))
plt.text(x=1.21, y=df.kernel_update_devi[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_devi[1]-df.kernel_update_scen[1], (df.kernel_update_devi[1]-df.kernel_update_scen[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))
plt.text(x=1.21, y=df.kernel_update_scen[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_scen[1]-df.kernel_update_node[1], (df.kernel_update_scen[1]-df.kernel_update_node[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))
plt.text(x=1.21, y=df.kernel_update_node[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_node[1]-df.kernel_update_simu[1], (df.kernel_update_node[1]-df.kernel_update_simu[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))


df = making_df(time_after_improve_butter)
butter_filter = [plt.bar([0-0.4, 1, 2], df.other, align='edge', edgecolor='black', width= 0.2,  color='grey'),
               plt.bar([0-0.4, 1, 2], df.odss_call, align='edge', edgecolor='black', width= 0.2, color='#1f77b4'),
               plt.bar([0-0.4, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2,  color='#ff7f0e'),
               plt.bar([0-0.4, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2,  color='#2ca02c'),
               
               plt.bar([0, 1-0.4, 2], df.kernel_update_devi, align='edge', edgecolor='black', width= 0.2,  color="#bcbd22"),
               plt.bar([0, 1-0.4, 2], df.device_update, align='edge', edgecolor='black', width= 0.2, color="#bcbd22", hatch="/"),
               plt.bar([0, 1-0.4, 2], df.kernel_update_scen, align='edge', edgecolor='black', width= 0.2,  color="#9467bd"),
               plt.bar([0, 1-0.4, 2], df.kernel_update_node, align='edge', edgecolor='black', width= 0.2,  color="#8c564b"),
               plt.bar([0, 1-0.4, 2], df.kernel_update_simu, align='edge', edgecolor='black', width= 0.2,  color="#e377c2"),
               ]

plt.text(x=-0.36, y=(df.other[0]+0.1)/2 , s="{:4.2f} s".format(df.other[0]) , fontdict=dict(fontsize=15))

plt.text(x=-0.395, y=df.other[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.other[0]-df.odss_call[0], (1-df.odss_call[0]/df.other[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=-0.395, y=df.odss_call[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.odss_call[0]-df.reset_env[0], ((df.odss_call[0]-df.reset_env[0])/df.other[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=-0.395, y=df.reset_env[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.other[0])*100) , fontdict=dict(fontsize=10))

plt.text(x=0.64, y=(df.kernel_update_devi[1]+0.1)/2 , s="{:4.2f} s".format(df.kernel_update_devi[1]) , fontdict=dict(fontsize=15))
plt.text(x=0.60, y=df.kernel_update_devi[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_devi[1]-df.kernel_update_scen[1], (df.kernel_update_devi[1]-df.kernel_update_scen[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))
plt.text(x=0.60, y=df.kernel_update_scen[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_scen[1]-df.kernel_update_node[1], (df.kernel_update_scen[1]-df.kernel_update_node[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))
plt.text(x=0.60, y=df.kernel_update_node[1]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.kernel_update_node[1]-df.kernel_update_simu[1], (df.kernel_update_node[1]-df.kernel_update_simu[1])/df.kernel_update_devi[1]*100) , fontdict=dict(fontsize=10))

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.init_env
# Out:
# 0    0.000044
# 1    0.000000
# 2    0.000000
# Name: init_env, dtype: float64

# %%
dir(old_filter[0])
old_filter[0]
# Out:
# 'other'

# %%
step = np.hstack((1 * np.ones(11), np.linspace(1, -1, 7), -1 * np.ones(11)))

output = np.array(x).copy()
# if k.time > 12:
if np.max(output[STEP_BUFFER:-STEP_BUFFER]) - np.min(output[STEP_BUFFER:-STEP_BUFFER]) > 0.004:
    norm_data = -1 + 2 * (list(output) - np.min(list(output))) / (np.max(list(output)) - np.min(list(output)))
    step_corr = np.convolve(norm_data, step, mode='valid')
    if np.max(abs(step_corr)) > 10:
        output = np.ones(15)
filter_data = output[STEP_BUFFER:-STEP_BUFFER]

# %%
#################### GLOBAL ENV ##########################
global_time_before_improve = {
"init env":  0.001071929931640625,
"rest env":  0.5132603645324707,
"step env":  0.5955072999000549,
"ttal env":  12.424493074417114,
"step only":  11.579830646514893
}

global_time_after_improve = {
"init env":  0.0010859966278076172,
"rest env":  0.5088710784912109,
"step env":  0.17844549417495728,
"ttal env":  4.078881740570068,
"step only":  3.2529635429382324
}

# %%
import pandas as pd

def making_df(d):
    df = pd.DataFrame(dict(
        init_env= [d['init env'], 0, 0],
        reset_env=[d['rest env']+d['init env'], 0, 0],
        step_only=[d['rest env']+d['init env'] + d['step only'], 0, 0], 
        ttal_env= [d['ttal env'], 0, 0],
        ))

    return df

import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20, 10))
plt.grid()
df = making_df(global_time_after_improve)
old_filter = [plt.bar([0, 1, 2], df.ttal_env, align='edge', edgecolor='black', width= 0.2, color='grey',label='total env'),
               plt.bar([0, 1, 2], df.step_only, align='edge', edgecolor='black', width= 0.2, label='step only',  color='#1f77b4'),
               plt.bar([0, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2, label='reset env',  color='#ff7f0e'),
               plt.bar([0, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2, label='init env',  color='#2ca02c'),
               ]

plt.text(x=0.05, y=(df.ttal_env[0]+0.1)/2 , s="{:4.2f} s".format(df.ttal_env[0]) , fontdict=dict(fontsize=15))
plt.text(x=0.02, y=df.ttal_env[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.ttal_env[0]-df.step_only[0], (1-df.step_only[0]/df.ttal_env[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=0.02, y=df.step_only[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.step_only[0]-df.reset_env[0], ((df.step_only[0]-df.reset_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=0.02, y=df.reset_env[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=10))


df = making_df(global_time_before_improve)
butter_filter = [plt.bar([0-0.2, 1, 2], df.ttal_env, align='edge', edgecolor='black', width= 0.2,  color='grey'),
               plt.bar([0-0.2, 1, 2], df.step_only, align='edge', edgecolor='black', width= 0.2, color='#1f77b4'),
               plt.bar([0-0.2, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2,  color='#ff7f0e'),
               plt.bar([0-0.2, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2,  color='#2ca02c'),
               ]

plt.text(x=-0.16, y=(df.ttal_env[0]+0.1)/2 , s="{:4.2f} s".format(df.ttal_env[0]) , fontdict=dict(fontsize=15))
plt.text(x=-0.18, y=df.ttal_env[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.ttal_env[0]-df.step_only[0], (1-df.step_only[0]/df.ttal_env[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=-0.18, y=df.step_only[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.step_only[0]-df.reset_env[0], ((df.step_only[0]-df.reset_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=10))
plt.text(x=-0.18, y=df.reset_env[0]+0.1 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=10))

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
############################### FULL TEST ####################################

# %%
lr6 = {
    'worker_1': {
        'grad_time_ms': 193.846,
        'sample_time_ms': 33367.888,
        'update_time_ms': 215.554,
        'mean_env_wait_ms': 1561.5891616593806,
        'mean_inference_ms': 2.8518164918156423,
        'mean_processing_ms': 88.84194779678869,
        'time_this_iter_s': 35.707825899124146,
    },
    'worker_2': {
        'grad_time_ms': 245.115,
        'sample_time_ms': 32911.972,
        'update_time_ms': 226.544,
        'mean_env_wait_ms': 1510.0952110612955,
        'mean_inference_ms': 3.18628228520342,
        'mean_processing_ms': 85.2532727680388,
        'time_this_iter_s': 36.67139267921448,
    },
    'worker_4': {
        'grad_time_ms': 555.349,
        'sample_time_ms': 33511.379,
        'update_time_ms': 207.503,
        'mean_env_wait_ms': 1496.0226550287177,
        'mean_inference_ms': 5.335363694374235,
        'mean_processing_ms': 85.34214470593703,
        'time_this_iter_s': 38.11227083206177,
    },
    'worker_6': {
        'grad_time_ms': 452.237,
        'sample_time_ms': 33931.339,
        'update_time_ms': 218.841,
        'mean_env_wait_ms': 1510.9196992870325,
        'mean_inference_ms': 3.2588439598051298,
        'mean_processing_ms': 85.06985702637598,
        'time_this_iter_s': 38.91789197921753,
    },
    'worker_8': {
        'grad_time_ms': 542.317,
        'sample_time_ms': 33421.223,
        'update_time_ms': 222.572,
        'mean_env_wait_ms': 1497.587206066334,
        'mean_inference_ms':3.26484239674218,
        'mean_processing_ms': 84.424420020689,
        'time_this_iter_s': 39.47864007949829,
    },
    'worker_10': {
        'grad_time_ms': 953.399,
        'sample_time_ms': 26557.233,
        'update_time_ms': 204.272,
        'mean_env_wait_ms': 1179.5590199454136,
        'mean_inference_ms': 12.886175468912912,
        'mean_processing_ms': 70.30062065308029,
        'time_this_iter_s': 31.64210319519043,
    },
    'worker_12': {
        'grad_time_ms': 644.432,
        'sample_time_ms': 26962.971,
        'update_time_ms': 193.204,
        'mean_env_wait_ms': 1184.0636614319817,
        'mean_inference_ms': 2.9941632013972654,
        'mean_processing_ms': 70.20790020433634,
        'time_this_iter_s': 33.664016008377075,
    },
    'worker_14': {
        'grad_time_ms': 720.741,
        'sample_time_ms': 27200.867,
        'update_time_ms': 216.561,
        'mean_env_wait_ms': 1193.946884104329,
        'mean_inference_ms': 2.7539293913453573,
        'mean_processing_ms': 70.35823189563675,
        'time_this_iter_s': 34.54695773124695,
    },
    'worker_18': {
        'grad_time_ms': 829.988,
        'sample_time_ms': 27350.961,
        'update_time_ms': 227.42,
        'mean_env_wait_ms': 1204.5597047195652,
        'mean_inference_ms': 2.8488342588384796,
        'mean_processing_ms': 71.57476564298882,
        'time_this_iter_s': 36.222097873687744,
    },
    'worker_22': {
        'grad_time_ms': 1085.89,
        'sample_time_ms': 27339.036,
        'update_time_ms': 225.194,
        'mean_env_wait_ms': 1207.2474081947973,
        'mean_inference_ms': 2.7852969230520155,
        'mean_processing_ms': 73.0798569428178,
        'time_this_iter_s': 39.806678771972656,
    },
    'worker_26': {
        'grad_time_ms': 1083.073,
        'sample_time_ms': 27323.759,
        'update_time_ms': 236.343,
        'mean_env_wait_ms': 1210.0073652191204,
        'mean_inference_ms': 2.809039236200397,
        'mean_processing_ms': 73.50533880311254,
        'time_this_iter_s': 41.6199004650116,
    },
    'worker_30': {
        'grad_time_ms': 1345.625,
        'sample_time_ms': 27458.341,
        'update_time_ms': 239.015,
        'mean_env_wait_ms': 1213.7220861397354,
        'mean_inference_ms': 2.8479123455043,
        'mean_processing_ms': 74.11064474503014,
        'time_this_iter_s': 42.66653037071228,
    },
}

lr_after = {
    'worker_1': {
        'mean_env_wait_ms': 359.85954005919046,
        'sample_time_ms': 8414.992,
        'time_this_iter_s': 11.156358003616333,
    },
    'worker_2': {
        'mean_env_wait_ms': 353.7760943341377,
        'sample_time_ms': 8329.385,
        'time_this_iter_s': 11.240424156188965,
    },
    'worker_4': {
        'mean_env_wait_ms': 356.03525363063517,
        'sample_time_ms': 8539.176,
        'time_this_iter_s': 12.54195237159729,
    },
    'worker_6': {
        'mean_env_wait_ms': 355.9104778380528,
        'sample_time_ms': 8495.713,
        'time_this_iter_s': 12.761571407318115,
    },
    'worker_8': {
        'mean_env_wait_ms': 355.4814142045082,
        'sample_time_ms': 8705.683,
        'time_this_iter_s': 13.611186265945435,
    },
    'worker_18': {
        'mean_env_wait_ms': 352.6312039021332,
        'sample_time_ms': 8552.302,
        'time_this_iter_s': 17.485107898712158,
    },
    'worker_26': {
        'mean_env_wait_ms': 301.5514406423355,
        'sample_time_ms': 7392.124,
        'time_this_iter_s': 15.31141471862793,
    },
    'worker_30': {
        'mean_env_wait_ms': 302.07566519747894,
        'sample_time_ms': 7311.093,
        'time_this_iter_s': 15.809455871582031,
    },
}

lr_after_no_worker = {'total_step_s': 3.891226053237915, 'mean_step_s': 0.1646345376968384}
#init env:  0.0011799335479736328
#rest env:  0.5973424911499023
#step env:  0.1646345376968384
#ttal env:  3.891226053237915
#step only:  3.0117061138153076

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(20,15))
tittle = 'sample_time_ms'
plt.title(tittle)
plt.xlabel('number workers')
plt.ylabel('second' if tittle[-2:] == '_s' else 'milisecond')
plt.plot([int(key[7:]) for key in lr6.keys()], [lr6[key][tittle] for key in lr6.keys()], label='lr6 32-cpu')
plt.scatter([int(key[7:]) for key in lr6.keys()], [lr6[key][tittle] for key in lr6.keys()])
plt.plot([int(key[7:]) for key in lr_after.keys()], [lr_after[key][tittle] for key in lr_after.keys()], label='lr6 32-cpu improved')
plt.scatter([int(key[7:]) for key in lr_after.keys()], [lr_after[key][tittle] for key in lr_after.keys()])
if tittle == 'sample_time_ms':
#    plt.hlines(local_no_worker['total_step_s'], 0, 30, linestyles='--', color='C0', label='Local (simulation only)')
#    plt.hlines(gig_no_worker['total_step_s'], 0, 30, linestyles='--', color='C1', label='GIG Server (simulation only)')
    plt.hlines(lr_after_no_worker['total_step_s']*1000, 0, 30, linestyles='--', color='C2', label='lr6 32-cpu improved(simulation only)')

#if tittle == 'mean_env_wait_ms':
#    plt.hlines(local_no_worker['mean_step_s']*1000, 0, 30, linestyles='--', color='C0', label='Local (simulation only)')
#    plt.hlines(gig_no_worker['mean_step_s']*1000, 0, 30, linestyles='--', color='C1', label='GIG Server (simulation only)')
#    plt.hlines(lr6_no_worker['mean_step_s']*1000, 0, 30, linestyles='--', color='C2', label='lr6 32-cpu (simulation only)')
plt.legend(loc=1)
plt.show()

# %%
#################### GLOBAL ENV ##########################
global_time_37 = {
"init env":  0.0010859966278076172,
"rest env":  0.5088710784912109,
"step env":  0.17844549417495728,
"ttal env":  4.078881740570068,
"step only":  3.2529635429382324
}

global_time_240 = {
"init env":  0.0012063980102539062,
"rest env":  3.11600399017334,
"step env":  0.9910755395889282,
"ttal env":  22.938740253448486,
"step only":  17.757638692855835
}

vectorized_global_time_240 = {
"init env":  0.0010447502136230469,
"rest env":  1.9284865856170654,
"step env":  0.5307628393173218,
"ttal env":  12.544803142547607,
"step only":  8.762798547744751
}

vectorized_global_time_37 = {
"init env":  0.0011506080627441406,
"rest env":  0.35543203353881836,
"step env":  0.11077661514282226,
"ttal env":  2.572131872177124,
"step only":  1.8664536476135254
}

gpu_vectorized_global_time_37 = {
"init env":  0.0012984275817871094,
"rest env":  0.5690324306488037,
"step env":  0.6644710779190064,
"ttal env":  13.859769344329834,
"step only":  12.916941165924072
}

gpu_vectorized_global_time_240 = {
"init env":  0.001129150390625,
"rest env":  2.344669818878174,
"step env":  4.407485008239746,
"ttal env":  90.4955222606659,
"step only":  85.60339856147766
}

# %%
import pandas as pd

def making_df(d):
    df = pd.DataFrame(dict(
        init_env= [d['init env'], 0, 0],
        reset_env=[d['rest env']+d['init env'], 0, 0],
        step_only=[d['rest env']+d['init env'] + d['step only'], 0, 0], 
        ttal_env= [d['ttal env'], 0, 0],
        ))

    return df

import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20, 10))
fig.suptitle('Environment execution time', fontsize=20)
plt.grid()
df = making_df(global_time_37)
old_filter = [plt.bar([0, 1, 2], df.ttal_env, align='edge', edgecolor='black', width= 0.2, color='grey',label='others'),
               plt.bar([0, 1, 2], df.step_only, align='edge', edgecolor='black', width= 0.2, label='step only',  color='#1f77b4'),
               plt.bar([0, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2, label='reset env',  color='#ff7f0e'),
               plt.bar([0, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2, label='init env',  color='#2ca02c'),
               ]

plt.text(x=0.05, y=(df.ttal_env[0]+0.1) , s="{:4.2f} s".format(df.ttal_env[0]) , fontdict=dict(fontsize=15))
plt.text(x=0.04, y=(df.ttal_env[0] - df.step_only[0] - 0.2)/2 + df.step_only[0] , s="{:4.2f} s, {:.2f}%".format(df.ttal_env[0]-df.step_only[0], (1-df.step_only[0]/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04, y=(df.step_only[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.step_only[0]-df.reset_env[0], ((df.step_only[0]-df.reset_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04, y=(df.reset_env[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))


df = making_df(vectorized_global_time_37)
old_filter = [plt.bar([0+0.2, 1, 2], df.ttal_env, align='edge', edgecolor='black', width= 0.2, color='grey',),
               plt.bar([0+0.2, 1, 2], df.step_only, align='edge', edgecolor='black', width= 0.2,  color='#1f77b4'),
               plt.bar([0+0.2, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2,  color='#ff7f0e'),
               plt.bar([0+0.2, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2, color='#2ca02c'),
               ]

plt.text(x=0.05+0.2, y=(df.ttal_env[0]+0.1) , s="{:4.2f} s".format(df.ttal_env[0]) , fontdict=dict(fontsize=15))
plt.text(x=0.04+0.2, y=(df.ttal_env[0] - df.step_only[0] - 0.2)/2 + df.step_only[0] , s="{:4.2f} s, {:.2f}%".format(df.ttal_env[0]-df.step_only[0], (1-df.step_only[0]/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04+0.2, y=(df.step_only[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.step_only[0]-df.reset_env[0], ((df.step_only[0]-df.reset_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04+0.2, y=(df.reset_env[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))

"""df = making_df(gpu_vectorized_global_time_37)
old_filter = [plt.bar([0+0.4, 1, 2], df.ttal_env, align='edge', edgecolor='black', width= 0.2, color='grey'),
               plt.bar([0+0.4, 1, 2], df.step_only, align='edge', edgecolor='black', width= 0.2, color='#1f77b4'),
               plt.bar([0+0.4, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2, color='#ff7f0e'),
               plt.bar([0+0.4, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2, color='#2ca02c'),
               ]

plt.text(x=0.05+0.4, y=(df.ttal_env[0]+0.1) , s="{:4.2f} s".format(df.ttal_env[0]) , fontdict=dict(fontsize=15))
plt.text(x=0.04+0.4, y=(df.ttal_env[0] - df.step_only[0] - 0.2)/2 + df.step_only[0] , s="{:4.2f} s, {:.2f}%".format(df.ttal_env[0]-df.step_only[0], (1-df.step_only[0]/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04+0.4, y=(df.step_only[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.step_only[0]-df.reset_env[0], ((df.step_only[0]-df.reset_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04+0.4, y=(df.reset_env[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
"""
#############################################################################

df = making_df(global_time_240)
butter_filter = [plt.bar([0+1, 1, 2], df.ttal_env, align='edge', edgecolor='black', width= 0.2,  color='grey'),
               plt.bar([0+1, 1, 2], df.step_only, align='edge', edgecolor='black', width= 0.2, color='#1f77b4'),
               plt.bar([0+1, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2,  color='#ff7f0e'),
               plt.bar([0+1, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2,  color='#2ca02c'),
               ]

plt.text(x=0.05+1, y=(df.ttal_env[0]+0.1) , s="{:4.2f} s".format(df.ttal_env[0]) , fontdict=dict(fontsize=15))
plt.text(x=0.04+1, y=(df.ttal_env[0] - df.step_only[0] - 0.2)/2 + df.step_only[0] , s="{:4.2f} s, {:.2f}%".format(df.ttal_env[0]-df.step_only[0], (1-df.step_only[0]/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04+1, y=(df.step_only[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.step_only[0]-df.reset_env[0], ((df.step_only[0]-df.reset_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04+1, y=(df.reset_env[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))


df = making_df(vectorized_global_time_240)
butter_filter = [plt.bar([0+1.2, 1, 2], df.ttal_env, align='edge', edgecolor='black', width= 0.2,  color='grey'),
               plt.bar([0+1.2, 1, 2], df.step_only, align='edge', edgecolor='black', width= 0.2, color='#1f77b4'),
               plt.bar([0+1.2, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2,  color='#ff7f0e'),
               plt.bar([0+1.2, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2,  color='#2ca02c'),
               ]

plt.text(x=0.05+1.2, y=(df.ttal_env[0]+0.1) , s="{:4.2f} s".format(df.ttal_env[0]) , fontdict=dict(fontsize=15))
plt.text(x=0.04+1.2, y=(df.ttal_env[0] - df.step_only[0] - 0.2)/2 + df.step_only[0] , s="{:4.2f} s, {:.2f}%".format(df.ttal_env[0]-df.step_only[0], (1-df.step_only[0]/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04+1.2, y=(df.step_only[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.step_only[0]-df.reset_env[0], ((df.step_only[0]-df.reset_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04+1.2, y=(df.reset_env[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))


"""df = making_df(gpu_vectorized_global_time_240)
butter_filter = [plt.bar([0+1.4, 1, 2], df.ttal_env, align='edge', edgecolor='black', width= 0.2,  color='grey'),
               plt.bar([0+1.4, 1, 2], df.step_only, align='edge', edgecolor='black', width= 0.2, color='#1f77b4'),
               plt.bar([0+1.4, 1, 2], df.reset_env, align='edge', edgecolor='black', width= 0.2,  color='#ff7f0e'),
               plt.bar([0+1.4, 1, 2], df.init_env, align='edge', edgecolor='black', width= 0.2,  color='#2ca02c'),
               ]

plt.text(x=0.05+1.4, y=(df.ttal_env[0]+0.1) , s="{:4.2f} s".format(df.ttal_env[0]) , fontdict=dict(fontsize=15))
plt.text(x=0.04+1.4, y=(df.ttal_env[0] - df.step_only[0] - 0.2)/2 + df.step_only[0] , s="{:4.2f} s, {:.2f}%".format(df.ttal_env[0]-df.step_only[0], (1-df.step_only[0]/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04+1.4, y=(df.step_only[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.step_only[0]-df.reset_env[0], ((df.step_only[0]-df.reset_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
plt.text(x=0.04+1.4, y=(df.reset_env[0]-0.2)/2 , s="{:4.2f} s, {:.2f}%".format(df.reset_env[0]-df.init_env[0], ((df.reset_env[0]-df.init_env[0])/df.ttal_env[0])*100) , fontdict=dict(fontsize=8))
"""
plt.xticks([0+0.1, 0+0.3, 0+0.5, 1+0.1, 1+0.3, 1+0.5], ['37-norm', '37-vec', '37-gpu', '240-norm', '240-vec', '240-gpu'])
plt.ylabel('second (s)', fontsize=16)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
