# %%
from pycigar.envs import Env
import yaml

import numpy as np
from scipy import signal
import math
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 6]

class FooEnv(Env):
    @property
    def observation_space(self):
        return Box(low=-float('inf'), high=float('inf'),
                   shape=(5,), dtype=np.float64)

    @property
    def action_space(self):
        return Box(low=0.5, high=1.5, shape=(5,), dtype=np.float64)

    def step(self, rl_actions=None, randomize_rl_update=None):
        """See parent class.
        """

        for _ in range(self.sim_params['env_config']["sims_per_step"]):
            self.env_time += 1
            
            # perform action update for PV inverter device
            if len(self.k.device.group_controllers.keys()) > 0:
                control_setting = []
                devices = []
                for group_controller_name, group_controller in self.k.device.group_controllers.items():
                    action = group_controller.get_action(self)
                    if isinstance(action, tuple):
                        if isinstance(group_controller.device_id, str):
                            devices.extend([group_controller.device_id])
                            control_setting.extend((action,))
                        else:
                            devices.extend(group_controller.device_id)
                            control_setting.extend((action,)*len(group_controller.device_id))
                    elif isinstance(action, dict):
                        devices.extend(action.keys())
                        control_setting.extend(action.values())
                self.k.device.apply_control(devices, control_setting)

            # perform action update for PV inverter device
            if len(self.k.device.get_local_device_ids()) > 0:
                control_setting = []
                for device_id in self.k.device.get_local_device_ids():
                    action = self.k.device.get_controller(device_id).get_action(self)
                    control_setting.append(action)
                self.k.device.apply_control(self.k.device.get_local_device_ids(), control_setting)


            self.additional_command()

            if self.k.time <= self.k.t:
                self.k.update(reset=False)

                # check whether the simulator sucessfully solved the powerflow
                converged = self.k.simulation.check_converged()
                if not converged:
                    break

            if self.k.time >= self.k.t:
                break

        # the episode will be finished if it is not converged.
        done = not converged or (self.k.time == self.k.t)
        obs = self.get_state()
        infos = {}
        reward = self.compute_reward(rl_actions)

        return obs, reward, done, infos

    def get_state(self):
        return [0, 0, 0, 0, 0]

    def compute_reward(self, rl_actions, **kwargs):
        return 0

stream = open("./IEEE_03_Node/pycigar_config_ieee_03_cent.yaml", "r")
sim_params = yaml.safe_load(stream)

print('Simulation Complete')
# Out:
# Simulation Complete

# %%
from pycigar.utils.registry import register_devcon
from pycigar.controllers.battery_storage_controller import BatteryStorageController
from pycigar.devices.battery_storage_device import BatteryStorageDevice
from pycigar.devices.battery_storage_device_advanced import BatteryStorageDeviceAdvanced

# from pycigar.controllers.battery_peak_shaving_controller import BatteryPeakShavingController
from pycigar.controllers.battery_peak_shaving_controller_dist import BatteryPeakShavingControllerDist
from pycigar.controllers.battery_peak_shaving_controller_cent import BatteryPeakShavingControllerCent

# register_devcon('battery_storage_controller', BatteryStorageController)
# register_devcon('battery_peak_shaving_controller', BatteryPeakShavingController)
register_devcon('battery_peak_shaving_controller_dist', BatteryPeakShavingControllerDist)
register_devcon('battery_peak_shaving_controller_cent', BatteryPeakShavingControllerCent)
register_devcon('battery_storage_device_advanced', BatteryStorageDeviceAdvanced)
# Out:
# 'battery_storage_device_advanced'

# %%
sim_params
# Out:
# {'is_disable_log': False,
#  'is_disable_y': False,
#  'vectorized_mode': False,
#  'env_config': {'clip_actions': 'True,', 'sims_per_step': 20},
#  'simulation_config': {'network_model_directory': '/home/michael/Desktop/git/ceds-cigar/pycigar/zzz/IEEE_03_Node/ieee3.dss',
#   'custom_configs': {'solution_mode': 1,
#    'solution_number': 1,
#    'solution_step_size': 1,
#    'solution_control_mode': -1,
#    'solution_max_control_iterations': 1000000,
#    'solution_max_iterations': 30000,
#    'power_factor': 0.9}},
#  'scenario_config': {'network_data_directory': '/home/michael/Desktop/git/ceds-cigar/pycigar/zzz/IEEE_03_Node/load_solar_data.csv',
#   'multi_config': False,
#   'start_end_time': [3600, 5401],
#   'custom_configs': {'load_scaling_factor': 1.25,
#    'solar_scaling_factor': 0,
#    'slack_bus_voltage': 1.04,
#    'load_generation_noise': False,
#    'power_factor': 0.9},
#   'nodes': [{'name': 's701a',
#     'devices': [{'name': 'pv_1',
#       'device': 'pv_device',
#       'custom_device_configs': {'default_control_setting': [0.98,
#         1.01,
#         1.01,
#         1.04,
#         1.06],
#        'gain': '1e5',
#        'low_pass_filter_measure_mean': 1.2,
#        'low_pass_filter_output_mean': 0.115},
#       'controller': 'fixed_controller',
#       'custom_controller_configs': {'default_control_setting': [0.98,
#         1.01,
#         1.01,
#         1.04,
#         1.06]}},
#      {'name': 'bsd_1',
#       'device': 'battery_storage_device_advanced',
#       'custom_device_configs': {'default_control_setting': 'standby',
#        'total_capacity': 10,
#        'current_capacity': 9.0,
#        'max_charge_power': 20.0,
#        'max_discharge_power': 25.0,
#        'max_ramp_rate': 0.1,
#        'max_SOC': 1.0,
#        'min_SOC': 0.2}}]},
#    {'name': 's702a',
#     'devices': [{'name': 'bsd_2',
#       'device': 'battery_storage_device_advanced',
#       'custom_device_configs': {'default_control_setting': 'standby',
#        'total_capacity': 10,
#        'current_capacity': 8.0,
#        'max_charge_power': 20.0,
#        'max_discharge_power': 30.0,
#        'max_ramp_rate': 0.1,
#        'max_SOC': 1.0,
#        'min_SOC': 0.2}}]},
#    {'name': 's703a',
#     'devices': [{'name': 'bsd_3',
#       'device': 'battery_storage_device_advanced',
#       'custom_device_configs': {'default_control_setting': 'standby',
#        'total_capacity': 10,
#        'current_capacity': 8.0,
#        'max_charge_power': 5.0,
#        'max_discharge_power': 10.0,
#        'max_ramp_rate': 0.1,
#        'max_SOC': 1.0,
#        'min_SOC': 0.2}}]}],
#   'controllers': [{'name': 'psc_1',
#     'controller': 'battery_peak_shaving_controller_dist',
#     'custom_controller_configs': {'default_control_setting': 'standby',
#      'lowpass_filter_frequency': 0.01,
#      'active_power_target': 750,
#      'eta': 0.01},
#     'list_devices': ['bsd_1']},
#    {'name': 'psc_2',
#     'controller': 'battery_peak_shaving_controller_dist',
#     'custom_controller_configs': {'default_control_setting': 'standby',
#      'lowpass_filter_frequency': 0.01,
#      'active_power_target': 750,
#      'eta': 0.01},
#     'list_devices': ['bsd_2']},
#    {'name': 'psc_3',
#     'controller': 'battery_peak_shaving_controller_dist',
#     'custom_controller_configs': {'default_control_setting': 'standby',
#      'lowpass_filter_frequency': 0.01,
#      'active_power_target': 750,
#      'eta': 0.01},
#     'list_devices': ['bsd_3']}]}}

# %%
env = FooEnv(sim_params)
env.reset()
done = False
while not done:
    _, _, done, _ = env.step()
    # if env.k.time % 60 == 0:
    #     print('Time: ' + str(env.k.time))
    # if env.k.time >= 55:
    #     done = True
    
print('Simulation Complete')
# Out:
# psc_1
# psc_2
# psc_3
# bsd_1
# 32400000.0
# bsd_2
# 28800000.0
# bsd_3
# 28800000.0
# bsd_1
# 32400000.0
# bsd_2
# 28800000.0
# bsd_3
# 28800000.0
# Time: 51
# Initialize: bsd_1
# Time: 51
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.9
# Measured active power lpf [kW]: 809.2184386867442
# Measured reactive power lpf [kVAr]: 493.58042594805687
# Measured apparent power lpf [kVA]: 947.869251737642
#
# Time: 51
# Initialize: bsd_2
# Time: 51
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.8
# Measured active power lpf [kW]: 809.2184386867442
# Measured reactive power lpf [kVAr]: 493.58042594805687
# Measured apparent power lpf [kVA]: 947.869251737642
#
# Time: 51
# Initialize: bsd_3
# Time: 51
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.8
# Measured active power lpf [kW]: 809.2184386867442
# Measured reactive power lpf [kVAr]: 493.58042594805687
# Measured apparent power lpf [kVA]: 947.869251737642
#
# Time: 52
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.9
# Measured active power lpf [kW]: 809.2249846743092
# Measured reactive power lpf [kVAr]: 493.58441830756243
# Measured apparent power lpf [kVA]: 947.8769191288238
# Discharge
# Discharge power [kW]: 0.5921843868674421
#
# Time: 52
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.8
# Measured active power lpf [kW]: 809.2249846743092
# Measured reactive power lpf [kVAr]: 493.58441830756243
# Measured apparent power lpf [kVA]: 947.8769191288238
# Discharge
# Discharge power [kW]: 0.5921843868674421
#
# Time: 52
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.8
# Measured active power lpf [kW]: 809.2249846743092
# Measured reactive power lpf [kVAr]: 493.58441830756243
# Measured apparent power lpf [kVA]: 947.8769191288238
# Discharge
# Discharge power [kW]: 0.5921843868674421
#
# Time: 53
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999972222222222
# Measured active power lpf [kW]: 809.2245362278546
# Measured reactive power lpf [kVAr]: 493.58855279079427
# Measured apparent power lpf [kVA]: 947.8786892209873
# Discharge
# Discharge power [kW]: 0.5922498467430921
#
# Time: 53
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999972222222222
# Measured active power lpf [kW]: 809.2245362278546
# Measured reactive power lpf [kVAr]: 493.58855279079427
# Measured apparent power lpf [kVA]: 947.8786892209873
# Discharge
# Discharge power [kW]: 0.5922498467430921
#
# Time: 53
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999972222222222
# Measured active power lpf [kW]: 809.2245362278546
# Measured reactive power lpf [kVAr]: 493.58855279079427
# Measured apparent power lpf [kVA]: 947.8786892209873
# Discharge
# Discharge power [kW]: 0.5922498467430921
#
# Time: 54
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999916666666666
# Measured active power lpf [kW]: 809.2438317468608
# Measured reactive power lpf [kVAr]: 493.6133400898469
# Measured apparent power lpf [kVA]: 947.9080697699521
# Discharge
# Discharge power [kW]: 1.1844297491459885
#
# Time: 54
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999916666666667
# Measured active power lpf [kW]: 809.2438317468608
# Measured reactive power lpf [kVAr]: 493.6133400898469
# Measured apparent power lpf [kVA]: 947.9080697699521
# Discharge
# Discharge power [kW]: 1.1844297491459885
#
# Time: 54
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999916666666667
# Measured active power lpf [kW]: 809.2438317468608
# Measured reactive power lpf [kVAr]: 493.6133400898469
# Measured apparent power lpf [kVA]: 947.9080697699521
# Discharge
# Discharge power [kW]: 1.1844297491459885
#
# Time: 55
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999833333333334
# Measured active power lpf [kW]: 809.3313671224971
# Measured reactive power lpf [kVAr]: 493.69577208598923
# Measured apparent power lpf [kVA]: 948.0257260137782
# Discharge
# Discharge power [kW]: 1.1846881642117002
#
# Time: 55
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999833333333334
# Measured active power lpf [kW]: 809.3313671224971
# Measured reactive power lpf [kVAr]: 493.69577208598923
# Measured apparent power lpf [kVA]: 948.0257260137782
# Discharge
# Discharge power [kW]: 1.1846881642117002
#
# Time: 55
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999833333333334
# Measured active power lpf [kW]: 809.3313671224971
# Measured reactive power lpf [kVAr]: 493.69577208598923
# Measured apparent power lpf [kVA]: 948.0257260137782
# Discharge
# Discharge power [kW]: 1.1846881642117002
#
# Time: 56
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999722222222222
# Measured active power lpf [kW]: 809.4139587383615
# Measured reactive power lpf [kVAr]: 493.77897162922983
# Measured apparent power lpf [kVA]: 948.1395622078671
# Discharge
# Discharge power [kW]: 1.7777434203709597
#
# Time: 56
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999722222222222
# Measured active power lpf [kW]: 809.4139587383615
# Measured reactive power lpf [kVAr]: 493.77897162922983
# Measured apparent power lpf [kVA]: 948.1395622078671
# Discharge
# Discharge power [kW]: 1.7777434203709597
#
# Time: 56
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999722222222222
# Measured active power lpf [kW]: 809.4139587383615
# Measured reactive power lpf [kVAr]: 493.77897162922983
# Measured apparent power lpf [kVA]: 948.1395622078671
# Discharge
# Discharge power [kW]: 1.7777434203709597
#
# Time: 57
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999583333333333
# Measured active power lpf [kW]: 809.4803060588993
# Measured reactive power lpf [kVAr]: 493.8542878294844
# Measured apparent power lpf [kVA]: 948.2354262021519
# Discharge
# Discharge power [kW]: 1.7788277515953157
#
# Time: 57
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999583333333333
# Measured active power lpf [kW]: 809.4803060588993
# Measured reactive power lpf [kVAr]: 493.8542878294844
# Measured apparent power lpf [kVA]: 948.2354262021519
# Discharge
# Discharge power [kW]: 1.7788277515953157
#
# Time: 57
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999583333333333
# Measured active power lpf [kW]: 809.4803060588993
# Measured reactive power lpf [kVAr]: 493.8542878294844
# Measured apparent power lpf [kVA]: 948.2354262021519
# Discharge
# Discharge power [kW]: 1.7788277515953157
#
# Time: 58
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999416666666666
# Measured active power lpf [kW]: 809.521528204912
# Measured reactive power lpf [kVAr]: 493.9153579207648
# Measured apparent power lpf [kVA]: 948.3024229733958
# Discharge
# Discharge power [kW]: 2.372546480959952
#
# Time: 58
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999416666666667
# Measured active power lpf [kW]: 809.521528204912
# Measured reactive power lpf [kVAr]: 493.9153579207648
# Measured apparent power lpf [kVA]: 948.3024229733958
# Discharge
# Discharge power [kW]: 2.372546480959952
#
# Time: 58
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999416666666667
# Measured active power lpf [kW]: 809.521528204912
# Measured reactive power lpf [kVAr]: 493.9153579207648
# Measured apparent power lpf [kVA]: 948.3024229733958
# Discharge
# Discharge power [kW]: 2.372546480959952
#
# Time: 59
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999222222222222
# Measured active power lpf [kW]: 809.5227590085437
# Measured reactive power lpf [kVAr]: 493.95079619476667
# Measured apparent power lpf [kVA]: 948.3219318428994
# Discharge
# Discharge power [kW]: 2.3740430336444356
#
# Time: 59
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999222222222222
# Measured active power lpf [kW]: 809.5227590085437
# Measured reactive power lpf [kVAr]: 493.95079619476667
# Measured apparent power lpf [kVA]: 948.3219318428994
# Discharge
# Discharge power [kW]: 2.3740430336444356
#
# Time: 59
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999222222222222
# Measured active power lpf [kW]: 809.5227590085437
# Measured reactive power lpf [kVAr]: 493.95079619476667
# Measured apparent power lpf [kVA]: 948.3219318428994
# Discharge
# Discharge power [kW]: 2.3740430336444356
#
# Time: 60
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999
# Measured active power lpf [kW]: 809.513573632635
# Measured reactive power lpf [kVAr]: 493.9819382958552
# Measured apparent power lpf [kVA]: 948.3303123163414
# Discharge
# Discharge power [kW]: 2.9677740710453895
#
# Time: 60
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999
# Measured active power lpf [kW]: 809.513573632635
# Measured reactive power lpf [kVAr]: 493.9819382958552
# Measured apparent power lpf [kVA]: 948.3303123163414
# Discharge
# Discharge power [kW]: 2.9677740710453895
#
# Time: 60
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999
# Measured active power lpf [kW]: 809.513573632635
# Measured reactive power lpf [kVAr]: 493.9819382958552
# Measured apparent power lpf [kVA]: 948.3303123163414
# Discharge
# Discharge power [kW]: 2.9677740710453895
#
# Time: 61
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.899875
# Measured active power lpf [kW]: 809.5122804905159
# Measured reactive power lpf [kVAr]: 494.02270075346325
# Measured apparent power lpf [kVA]: 948.3504421492624
# Discharge
# Discharge power [kW]: 2.969178769970786
#
# Time: 61
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.799875
# Measured active power lpf [kW]: 809.5122804905159
# Measured reactive power lpf [kVAr]: 494.02270075346325
# Measured apparent power lpf [kVA]: 948.3504421492624
# Discharge
# Discharge power [kW]: 2.969178769970786
#
# Time: 61
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.799875
# Measured active power lpf [kW]: 809.5122804905159
# Measured reactive power lpf [kVAr]: 494.02270075346325
# Measured apparent power lpf [kVA]: 948.3504421492624
# Discharge
# Discharge power [kW]: 2.969178769970786
#
# Time: 62
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8998472222222222
# Measured active power lpf [kW]: 809.5025532029216
# Measured reactive power lpf [kVAr]: 494.0603651059784
# Measured apparent power lpf [kVA]: 948.3617600951135
# Discharge
# Discharge power [kW]: 3.5628968759505484
#
# Time: 62
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7998472222222223
# Measured active power lpf [kW]: 809.5025532029216
# Measured reactive power lpf [kVAr]: 494.0603651059784
# Measured apparent power lpf [kVA]: 948.3617600951135
# Discharge
# Discharge power [kW]: 3.5628968759505484
#
# Time: 62
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7998472222222223
# Measured active power lpf [kW]: 809.5025532029216
# Measured reactive power lpf [kVAr]: 494.0603651059784
# Measured apparent power lpf [kVA]: 948.3617600951135
# Discharge
# Discharge power [kW]: 3.5628968759505484
#
# Time: 63
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8998166666666667
# Measured active power lpf [kW]: 809.511746505352
# Measured reactive power lpf [kVAr]: 494.11589670648846
# Measured apparent power lpf [kVA]: 948.398538120026
# Discharge
# Discharge power [kW]: 3.564204302000002
#
# Time: 63
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7998166666666666
# Measured active power lpf [kW]: 809.511746505352
# Measured reactive power lpf [kVAr]: 494.11589670648846
# Measured apparent power lpf [kVA]: 948.398538120026
# Discharge
# Discharge power [kW]: 3.564204302000002
#
# Time: 63
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7998166666666666
# Measured active power lpf [kW]: 809.511746505352
# Measured reactive power lpf [kVAr]: 494.11589670648846
# Measured apparent power lpf [kVA]: 948.398538120026
# Discharge
# Discharge power [kW]: 3.564204302000002
#
# Time: 64
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8997833333333334
# Measured active power lpf [kW]: 809.4932754097875
# Measured reactive power lpf [kVAr]: 494.154047253617
# Measured apparent power lpf [kVA]: 948.4026493798908
# Discharge
# Discharge power [kW]: 4.158014341004068
#
# Time: 64
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7997833333333333
# Measured active power lpf [kW]: 809.4932754097875
# Measured reactive power lpf [kVAr]: 494.154047253617
# Measured apparent power lpf [kVA]: 948.4026493798908
# Discharge
# Discharge power [kW]: 4.158014341004068
#
# Time: 64
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7997833333333333
# Measured active power lpf [kW]: 809.4932754097875
# Measured reactive power lpf [kVAr]: 494.154047253617
# Measured apparent power lpf [kVA]: 948.4026493798908
# Discharge
# Discharge power [kW]: 4.158014341004068
#
# Time: 65
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8997472222222223
# Measured active power lpf [kW]: 809.4568999041622
# Measured reactive power lpf [kVAr]: 494.181745976327
# Measured apparent power lpf [kVA]: 948.386034723555
# Discharge
# Discharge power [kW]: 4.159137056097878
#
# Time: 65
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7997472222222223
# Measured active power lpf [kW]: 809.4568999041622
# Measured reactive power lpf [kVAr]: 494.181745976327
# Measured apparent power lpf [kVA]: 948.386034723555
# Discharge
# Discharge power [kW]: 4.159137056097878
#
# Time: 65
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7997472222222223
# Measured active power lpf [kW]: 809.4568999041622
# Measured reactive power lpf [kVAr]: 494.181745976327
# Measured apparent power lpf [kVA]: 948.386034723555
# Discharge
# Discharge power [kW]: 4.159137056097878
#
# Time: 66
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8997083333333333
# Measured active power lpf [kW]: 809.425575140376
# Measured reactive power lpf [kVAr]: 494.2175317980568
# Measured apparent power lpf [kVA]: 948.3779470379369
# Discharge
# Discharge power [kW]: 4.752583340045691
#
# Time: 66
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7997083333333334
# Measured active power lpf [kW]: 809.425575140376
# Measured reactive power lpf [kVAr]: 494.2175317980568
# Measured apparent power lpf [kVA]: 948.3779470379369
# Discharge
# Discharge power [kW]: 4.752583340045691
#
# Time: 66
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7997083333333334
# Measured active power lpf [kW]: 809.425575140376
# Measured reactive power lpf [kVAr]: 494.2175317980568
# Measured apparent power lpf [kVA]: 948.3779470379369
# Discharge
# Discharge power [kW]: 4.752583340045691
#
# Time: 67
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8996666666666666
# Measured active power lpf [kW]: 809.3608933661574
# Measured reactive power lpf [kVAr]: 494.2310798685276
# Measured apparent power lpf [kVA]: 948.3298034009451
# Discharge
# Discharge power [kW]: 4.753392807501639
#
# Time: 67
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7996666666666666
# Measured active power lpf [kW]: 809.3608933661574
# Measured reactive power lpf [kVAr]: 494.2310798685276
# Measured apparent power lpf [kVA]: 948.3298034009451
# Discharge
# Discharge power [kW]: 4.753392807501639
#
# Time: 67
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7996666666666666
# Measured active power lpf [kW]: 809.3608933661574
# Measured reactive power lpf [kVAr]: 494.2310798685276
# Measured apparent power lpf [kVA]: 948.3298034009451
# Discharge
# Discharge power [kW]: 4.753392807501639
#
# Time: 68
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8996222222222222
# Measured active power lpf [kW]: 809.2630835819423
# Measured reactive power lpf [kVAr]: 494.2221020851876
# Measured apparent power lpf [kVA]: 948.2416488628072
# Discharge
# Discharge power [kW]: 5.346192273707264
#
# Time: 68
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7996222222222222
# Measured active power lpf [kW]: 809.2630835819423
# Measured reactive power lpf [kVAr]: 494.2221020851876
# Measured apparent power lpf [kVA]: 948.2416488628072
# Discharge
# Discharge power [kW]: 5.346192273707264
#
# Time: 68
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7996222222222222
# Measured active power lpf [kW]: 809.2630835819423
# Measured reactive power lpf [kVAr]: 494.2221020851876
# Measured apparent power lpf [kVA]: 948.2416488628072
# Discharge
# Discharge power [kW]: 5.346192273707264
#
# Time: 69
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.899575
# Measured active power lpf [kW]: 809.1574509499447
# Measured reactive power lpf [kVAr]: 494.2107609957884
# Measured apparent power lpf [kVA]: 948.1455883522575
# Discharge
# Discharge power [kW]: 5.346023643321062
#
# Time: 69
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.799575
# Measured active power lpf [kW]: 809.1574509499447
# Measured reactive power lpf [kVAr]: 494.2107609957884
# Measured apparent power lpf [kVA]: 948.1455883522575
# Discharge
# Discharge power [kW]: 5.346023643321062
#
# Time: 69
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.799575
# Measured active power lpf [kW]: 809.1574509499447
# Measured reactive power lpf [kVAr]: 494.2107609957884
# Measured apparent power lpf [kVA]: 948.1455883522575
# Discharge
# Discharge power [kW]: 5.346023643321062
#
# Time: 70
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.899525
# Measured active power lpf [kW]: 809.0343260010852
# Measured reactive power lpf [kVAr]: 494.1882486017724
# Measured apparent power lpf [kVA]: 948.0287789429799
# Discharge
# Discharge power [kW]: 5.937766783206712
#
# Time: 70
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.799525
# Measured active power lpf [kW]: 809.0343260010852
# Measured reactive power lpf [kVAr]: 494.1882486017724
# Measured apparent power lpf [kVA]: 948.0287789429799
# Discharge
# Discharge power [kW]: 5.937766783206712
#
# Time: 70
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.799525
# Measured active power lpf [kW]: 809.0343260010852
# Measured reactive power lpf [kVAr]: 494.1882486017724
# Measured apparent power lpf [kVA]: 948.0287789429799
# Discharge
# Discharge power [kW]: 5.937766783206712
#
# Time: 71
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8994722222222222
# Measured active power lpf [kW]: 808.8988170267452
# Measured reactive power lpf [kVAr]: 494.1577471299954
# Measured apparent power lpf [kVA]: 947.8972387531574
# Discharge
# Discharge power [kW]: 5.936366903331914
#
# Time: 71
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7994722222222223
# Measured active power lpf [kW]: 808.8988170267452
# Measured reactive power lpf [kVAr]: 494.1577471299954
# Measured apparent power lpf [kVA]: 947.8972387531574
# Discharge
# Discharge power [kW]: 5.936366903331914
#
# Time: 71
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7994722222222223
# Measured active power lpf [kW]: 808.8988170267452
# Measured reactive power lpf [kVAr]: 494.1577471299954
# Measured apparent power lpf [kVA]: 947.8972387531574
# Discharge
# Discharge power [kW]: 5.936366903331914
#
# Time: 72
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8994166666666666
# Measured active power lpf [kW]: 808.7548880792136
# Measured reactive power lpf [kVAr]: 494.12379469552803
# Measured apparent power lpf [kVA]: 947.7567163973727
# Discharge
# Discharge power [kW]: 6.526754953474164
#
# Time: 72
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7994166666666667
# Measured active power lpf [kW]: 808.7548880792136
# Measured reactive power lpf [kVAr]: 494.12379469552803
# Measured apparent power lpf [kVA]: 947.7567163973727
# Discharge
# Discharge power [kW]: 6.526754953474164
#
# Time: 72
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7994166666666667
# Measured active power lpf [kW]: 808.7548880792136
# Measured reactive power lpf [kVAr]: 494.12379469552803
# Measured apparent power lpf [kVA]: 947.7567163973727
# Discharge
# Discharge power [kW]: 6.526754953474164
#
# Time: 73
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8993583333333334
# Measured active power lpf [kW]: 808.6285272726536
# Measured reactive power lpf [kVAr]: 494.10588790024275
# Measured apparent power lpf [kVA]: 947.6395536156286
# Discharge
# Discharge power [kW]: 6.52391578412405
#
# Time: 73
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7993583333333333
# Measured active power lpf [kW]: 808.6285272726536
# Measured reactive power lpf [kVAr]: 494.10588790024275
# Measured apparent power lpf [kVA]: 947.6395536156286
# Discharge
# Discharge power [kW]: 6.52391578412405
#
# Time: 73
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7993583333333333
# Measured active power lpf [kW]: 808.6285272726536
# Measured reactive power lpf [kVAr]: 494.10588790024275
# Measured apparent power lpf [kVA]: 947.6395536156286
# Discharge
# Discharge power [kW]: 6.52391578412405
#
# Time: 74
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8992972222222222
# Measured active power lpf [kW]: 808.5114454438777
# Measured reactive power lpf [kVAr]: 494.0979646024502
# Measured apparent power lpf [kVA]: 947.5355170324924
# Discharge
# Discharge power [kW]: 7.113040226200701
#
# Time: 74
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7992972222222222
# Measured active power lpf [kW]: 808.5114454438777
# Measured reactive power lpf [kVAr]: 494.0979646024502
# Measured apparent power lpf [kVA]: 947.5355170324924
# Discharge
# Discharge power [kW]: 7.113040226200701
#
# Time: 74
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7992972222222222
# Measured active power lpf [kW]: 808.5114454438777
# Measured reactive power lpf [kVAr]: 494.0979646024502
# Measured apparent power lpf [kVA]: 947.5355170324924
# Discharge
# Discharge power [kW]: 7.113040226200701
#
# Time: 75
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8992333333333333
# Measured active power lpf [kW]: 808.3903516569643
# Measured reactive power lpf [kVAr]: 494.0901324220392
# Measured apparent power lpf [kVA]: 947.4281078841278
# Discharge
# Discharge power [kW]: 7.109030238562827
#
# Time: 75
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7992333333333334
# Measured active power lpf [kW]: 808.3903516569643
# Measured reactive power lpf [kVAr]: 494.0901324220392
# Measured apparent power lpf [kVA]: 947.4281078841278
# Discharge
# Discharge power [kW]: 7.109030238562827
#
# Time: 75
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7992333333333334
# Measured active power lpf [kW]: 808.3903516569643
# Measured reactive power lpf [kVAr]: 494.0901324220392
# Measured apparent power lpf [kVA]: 947.4281078841278
# Discharge
# Discharge power [kW]: 7.109030238562827
#
# Time: 76
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8991666666666667
# Measured active power lpf [kW]: 808.2907784991887
# Measured reactive power lpf [kVAr]: 494.10095169853463
# Measured apparent power lpf [kVA]: 947.3487916687403
# Discharge
# Discharge power [kW]: 7.696943742770344
#
# Time: 76
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7991666666666667
# Measured active power lpf [kW]: 808.2907784991887
# Measured reactive power lpf [kVAr]: 494.10095169853463
# Measured apparent power lpf [kVA]: 947.3487916687403
# Discharge
# Discharge power [kW]: 7.696943742770344
#
# Time: 76
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7991666666666667
# Measured active power lpf [kW]: 808.2907784991887
# Measured reactive power lpf [kVAr]: 494.10095169853463
# Measured apparent power lpf [kVA]: 947.3487916687403
# Discharge
# Discharge power [kW]: 7.696943742770344
#
# Time: 77
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8990972222222222
# Measured active power lpf [kW]: 808.1615412562138
# Measured reactive power lpf [kVAr]: 494.09128442000264
# Measured apparent power lpf [kVA]: 947.2334844722429
# Discharge
# Discharge power [kW]: 7.691938023554714
#
# Time: 77
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7990972222222222
# Measured active power lpf [kW]: 808.1615412562138
# Measured reactive power lpf [kVAr]: 494.09128442000264
# Measured apparent power lpf [kVA]: 947.2334844722429
# Discharge
# Discharge power [kW]: 7.691938023554714
#
# Time: 77
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7990972222222222
# Measured active power lpf [kW]: 808.1615412562138
# Measured reactive power lpf [kVAr]: 494.09128442000264
# Measured apparent power lpf [kVA]: 947.2334844722429
# Discharge
# Discharge power [kW]: 7.691938023554714
#
# Time: 78
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.899025
# Measured active power lpf [kW]: 808.0278326482676
# Measured reactive power lpf [kVAr]: 494.0813156206989
# Measured apparent power lpf [kVA]: 947.1142089419509
# Discharge
# Discharge power [kW]: 8.278559155332482
#
# Time: 78
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.799025
# Measured active power lpf [kW]: 808.0278326482676
# Measured reactive power lpf [kVAr]: 494.0813156206989
# Measured apparent power lpf [kVA]: 947.1142089419509
# Discharge
# Discharge power [kW]: 8.278559155332482
#
# Time: 78
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.799025
# Measured active power lpf [kW]: 808.0278326482676
# Measured reactive power lpf [kVAr]: 494.0813156206989
# Measured apparent power lpf [kVA]: 947.1142089419509
# Discharge
# Discharge power [kW]: 8.278559155332482
#
# Time: 79
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.89895
# Measured active power lpf [kW]: 807.9255265665631
# Measured reactive power lpf [kVAr]: 494.0973800556223
# Measured apparent power lpf [kVA]: 947.0353095084091
# Discharge
# Discharge power [kW]: 8.27221635003739
#
# Time: 79
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.79895
# Measured active power lpf [kW]: 807.9255265665631
# Measured reactive power lpf [kVAr]: 494.0973800556223
# Measured apparent power lpf [kVA]: 947.0353095084091
# Discharge
# Discharge power [kW]: 8.27221635003739
#
# Time: 79
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.79895
# Measured active power lpf [kW]: 807.9255265665631
# Measured reactive power lpf [kVAr]: 494.0973800556223
# Measured apparent power lpf [kVA]: 947.0353095084091
# Discharge
# Discharge power [kW]: 8.27221635003739
#
# Time: 80
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8988722222222222
# Measured active power lpf [kW]: 807.8020935597804
# Measured reactive power lpf [kVAr]: 494.09935780624784
# Measured apparent power lpf [kVA]: 946.9310417047857
# Discharge
# Discharge power [kW]: 8.857814420998114
#
# Time: 80
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7988722222222222
# Measured active power lpf [kW]: 807.8020935597804
# Measured reactive power lpf [kVAr]: 494.09935780624784
# Measured apparent power lpf [kVA]: 946.9310417047857
# Discharge
# Discharge power [kW]: 8.857814420998114
#
# Time: 80
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7988722222222222
# Measured active power lpf [kW]: 807.8020935597804
# Measured reactive power lpf [kVAr]: 494.09935780624784
# Measured apparent power lpf [kVA]: 946.9310417047857
# Discharge
# Discharge power [kW]: 8.857814420998114
#
# Time: 81
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8987916666666667
# Measured active power lpf [kW]: 807.6626202561883
# Measured reactive power lpf [kVAr]: 494.09060873135707
# Measured apparent power lpf [kVA]: 946.8074977499994
# Discharge
# Discharge power [kW]: 8.850237285635194
#
# Time: 81
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7987916666666667
# Measured active power lpf [kW]: 807.6626202561883
# Measured reactive power lpf [kVAr]: 494.09060873135707
# Measured apparent power lpf [kVA]: 946.8074977499994
# Discharge
# Discharge power [kW]: 8.850237285635194
#
# Time: 81
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7987916666666667
# Measured active power lpf [kW]: 807.6626202561883
# Measured reactive power lpf [kVAr]: 494.09060873135707
# Measured apparent power lpf [kVA]: 946.8074977499994
# Discharge
# Discharge power [kW]: 8.850237285635194
#
# Time: 82
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8987083333333333
# Measured active power lpf [kW]: 807.4965516904091
# Measured reactive power lpf [kVAr]: 494.0630878437997
# Measured apparent power lpf [kVA]: 946.6514753390773
# Discharge
# Discharge power [kW]: 9.434440623559997
#
# Time: 82
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7987083333333334
# Measured active power lpf [kW]: 807.4965516904091
# Measured reactive power lpf [kVAr]: 494.0630878437997
# Measured apparent power lpf [kVA]: 946.6514753390773
# Discharge
# Discharge power [kW]: 9.434440623559997
#
# Time: 82
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7987083333333334
# Measured active power lpf [kW]: 807.4965516904091
# Measured reactive power lpf [kVAr]: 494.0630878437997
# Measured apparent power lpf [kVA]: 946.6514753390773
# Discharge
# Discharge power [kW]: 9.434440623559997
#
# Time: 83
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8986222222222222
# Measured active power lpf [kW]: 807.3056548833217
# Measured reactive power lpf [kVAr]: 494.0179939998439
# Measured apparent power lpf [kVA]: 946.4651070178016
# Discharge
# Discharge power [kW]: 9.425202802539285
#
# Time: 83
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7986222222222222
# Measured active power lpf [kW]: 807.3056548833217
# Measured reactive power lpf [kVAr]: 494.0179939998439
# Measured apparent power lpf [kVA]: 946.4651070178016
# Discharge
# Discharge power [kW]: 9.425202802539285
#
# Time: 83
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7986222222222222
# Measured active power lpf [kW]: 807.3056548833217
# Measured reactive power lpf [kVAr]: 494.0179939998439
# Measured apparent power lpf [kVA]: 946.4651070178016
# Discharge
# Discharge power [kW]: 9.425202802539285
#
# Time: 84
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8985333333333333
# Measured active power lpf [kW]: 807.0899579968134
# Measured reactive power lpf [kVAr]: 493.9563099212172
# Measured apparent power lpf [kVA]: 946.2489294103765
# Discharge
# Discharge power [kW]: 10.007497172393213
#
# Time: 84
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7985333333333333
# Measured active power lpf [kW]: 807.0899579968134
# Measured reactive power lpf [kVAr]: 493.9563099212172
# Measured apparent power lpf [kVA]: 946.2489294103765
# Discharge
# Discharge power [kW]: 10.007497172393213
#
# Time: 84
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7985333333333333
# Measured active power lpf [kW]: 807.0899579968134
# Measured reactive power lpf [kVAr]: 493.9563099212172
# Measured apparent power lpf [kVA]: 946.2489294103765
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 85
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8984416666666667
# Measured active power lpf [kW]: 806.8395919511853
# Measured reactive power lpf [kVAr]: 493.8704751821783
# Measured apparent power lpf [kVA]: 945.9905778582712
# Discharge
# Discharge power [kW]: 9.99610238250742
#
# Time: 85
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7984416666666667
# Measured active power lpf [kW]: 806.8395919511853
# Measured reactive power lpf [kVAr]: 493.8704751821783
# Measured apparent power lpf [kVA]: 945.9905778582712
# Discharge
# Discharge power [kW]: 9.99610238250742
#
# Time: 85
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7984416666666667
# Measured active power lpf [kW]: 806.8395919511853
# Measured reactive power lpf [kVAr]: 493.8704751821783
# Measured apparent power lpf [kVA]: 945.9905778582712
# Discharge
# Discharge power [kW]: 9.99610238250742
#
# Time: 86
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8983472222222222
# Measured active power lpf [kW]: 806.5748901736525
# Measured reactive power lpf [kVAr]: 493.77574200556757
# Measured apparent power lpf [kVA]: 945.7153572041582
# Discharge
# Discharge power [kW]: 10.575893091905066
#
# Time: 86
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7983472222222222
# Measured active power lpf [kW]: 806.5748901736525
# Measured reactive power lpf [kVAr]: 493.77574200556757
# Measured apparent power lpf [kVA]: 945.7153572041582
# Discharge
# Discharge power [kW]: 10.575893091905066
#
# Time: 86
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7983472222222222
# Measured active power lpf [kW]: 806.5748901736525
# Measured reactive power lpf [kVAr]: 493.77574200556757
# Measured apparent power lpf [kVA]: 945.7153572041582
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 87
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.89825
# Measured active power lpf [kW]: 806.3090290675256
# Measured reactive power lpf [kVAr]: 493.6822800766387
# Measured apparent power lpf [kVA]: 945.4398151217688
# Discharge
# Discharge power [kW]: 10.561851284243945
#
# Time: 87
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.79825
# Measured active power lpf [kW]: 806.3090290675256
# Measured reactive power lpf [kVAr]: 493.6822800766387
# Measured apparent power lpf [kVA]: 945.4398151217688
# Discharge
# Discharge power [kW]: 10.561851284243945
#
# Time: 87
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.79825
# Measured active power lpf [kW]: 806.3090290675256
# Measured reactive power lpf [kVAr]: 493.6822800766387
# Measured apparent power lpf [kVA]: 945.4398151217688
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 88
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.89815
# Measured active power lpf [kW]: 806.0629446696565
# Measured reactive power lpf [kVAr]: 493.60517220515555
# Measured apparent power lpf [kVA]: 945.1896829722588
# Discharge
# Discharge power [kW]: 11.13898338258032
#
# Time: 88
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.79815
# Measured active power lpf [kW]: 806.0629446696565
# Measured reactive power lpf [kVAr]: 493.60517220515555
# Measured apparent power lpf [kVA]: 945.1896829722588
# Discharge
# Discharge power [kW]: 11.13898338258032
#
# Time: 88
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.79815
# Measured active power lpf [kW]: 806.0629446696565
# Measured reactive power lpf [kVAr]: 493.60517220515555
# Measured apparent power lpf [kVA]: 945.1896829722588
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 89
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8980472222222222
# Measured active power lpf [kW]: 805.8098314914328
# Measured reactive power lpf [kVAr]: 493.52451876785784
# Measured apparent power lpf [kVA]: 944.9317092537941
# Discharge
# Discharge power [kW]: 11.12248073094051
#
# Time: 89
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7980472222222222
# Measured active power lpf [kW]: 805.8098314914328
# Measured reactive power lpf [kVAr]: 493.52451876785784
# Measured apparent power lpf [kVA]: 944.9317092537941
# Discharge
# Discharge power [kW]: 11.12248073094051
#
# Time: 89
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7980472222222222
# Measured active power lpf [kW]: 805.8098314914328
# Measured reactive power lpf [kVAr]: 493.52451876785784
# Measured apparent power lpf [kVA]: 944.9317092537941
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 90
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8979416666666666
# Measured active power lpf [kW]: 805.5517382843942
# Measured reactive power lpf [kVAr]: 493.4414601458507
# Measured apparent power lpf [kVA]: 944.6682368132625
# Discharge
# Discharge power [kW]: 11.697081697494648
#
# Time: 90
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7979416666666667
# Measured active power lpf [kW]: 805.5517382843942
# Measured reactive power lpf [kVAr]: 493.4414601458507
# Measured apparent power lpf [kVA]: 944.6682368132625
# Discharge
# Discharge power [kW]: 11.697081697494648
#
# Time: 90
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7979416666666667
# Measured active power lpf [kW]: 805.5517382843942
# Measured reactive power lpf [kVAr]: 493.4414601458507
# Measured apparent power lpf [kVA]: 944.6682368132625
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 91
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8978333333333334
# Measured active power lpf [kW]: 805.3122709848132
# Measured reactive power lpf [kVAr]: 493.37382267194477
# Measured apparent power lpf [kVA]: 944.4287070481523
# Discharge
# Discharge power [kW]: 11.67799811378445
#
# Time: 91
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7978333333333333
# Measured active power lpf [kW]: 805.3122709848132
# Measured reactive power lpf [kVAr]: 493.37382267194477
# Measured apparent power lpf [kVA]: 944.4287070481523
# Discharge
# Discharge power [kW]: 11.67799811378445
#
# Time: 91
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7978333333333333
# Measured active power lpf [kW]: 805.3122709848132
# Measured reactive power lpf [kVAr]: 493.37382267194477
# Measured apparent power lpf [kVA]: 944.4287070481523
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 92
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8977222222222222
# Measured active power lpf [kW]: 805.0822185464639
# Measured reactive power lpf [kVAr]: 493.3147951355655
# Measured apparent power lpf [kVA]: 944.2017081743398
# Discharge
# Discharge power [kW]: 12.250204407342778
#
# Time: 92
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7977222222222222
# Measured active power lpf [kW]: 805.0822185464639
# Measured reactive power lpf [kVAr]: 493.3147951355655
# Measured apparent power lpf [kVA]: 944.2017081743398
# Discharge
# Discharge power [kW]: 12.250204407342778
#
# Time: 92
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7977222222222222
# Measured active power lpf [kW]: 805.0822185464639
# Measured reactive power lpf [kVAr]: 493.3147951355655
# Measured apparent power lpf [kVA]: 944.2017081743398
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 93
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8976083333333333
# Measured active power lpf [kW]: 804.8594977363944
# Measured reactive power lpf [kVAr]: 493.2625002904134
# Measured apparent power lpf [kVA]: 943.9844836061826
# Discharge
# Discharge power [kW]: 12.22882029924909
#
# Time: 93
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7976083333333334
# Measured active power lpf [kW]: 804.8594977363944
# Measured reactive power lpf [kVAr]: 493.2625002904134
# Measured apparent power lpf [kVA]: 943.9844836061826
# Discharge
# Discharge power [kW]: 12.22882029924909
#
# Time: 93
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7976083333333334
# Measured active power lpf [kW]: 804.8594977363944
# Measured reactive power lpf [kVAr]: 493.2625002904134
# Measured apparent power lpf [kVA]: 943.9844836061826
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 94
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8974916666666667
# Measured active power lpf [kW]: 804.6195061528616
# Measured reactive power lpf [kVAr]: 493.1988738766184
# Measured apparent power lpf [kVA]: 943.7466179408748
# Discharge
# Discharge power [kW]: 12.798799384706722
#
# Time: 94
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7974916666666667
# Measured active power lpf [kW]: 804.6195061528616
# Measured reactive power lpf [kVAr]: 493.1988738766184
# Measured apparent power lpf [kVA]: 943.7466179408748
# Discharge
# Discharge power [kW]: 12.798799384706722
#
# Time: 94
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7974916666666667
# Measured active power lpf [kW]: 804.6195061528616
# Measured reactive power lpf [kVAr]: 493.1988738766184
# Measured apparent power lpf [kVA]: 943.7466179408748
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 95
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8973722222222222
# Measured active power lpf [kW]: 804.4015885408944
# Measured reactive power lpf [kVAr]: 493.15282836585556
# Measured apparent power lpf [kVA]: 943.5367654587485
# Discharge
# Discharge power [kW]: 12.775015360777706
#
# Time: 95
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7973722222222223
# Measured active power lpf [kW]: 804.4015885408944
# Measured reactive power lpf [kVAr]: 493.15282836585556
# Measured apparent power lpf [kVA]: 943.5367654587485
# Discharge
# Discharge power [kW]: 12.775015360777706
#
# Time: 95
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7973722222222223
# Measured active power lpf [kW]: 804.4015885408944
# Measured reactive power lpf [kVAr]: 493.15282836585556
# Measured apparent power lpf [kVA]: 943.5367654587485
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 96
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.89725
# Measured active power lpf [kW]: 804.226457026869
# Measured reactive power lpf [kVAr]: 493.1410111512887
# Measured apparent power lpf [kVA]: 943.3812861517372
# Discharge
# Discharge power [kW]: 13.342815270115667
#
# Time: 96
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.79725
# Measured active power lpf [kW]: 804.226457026869
# Measured reactive power lpf [kVAr]: 493.1410111512887
# Measured apparent power lpf [kVA]: 943.3812861517372
# Discharge
# Discharge power [kW]: 13.342815270115667
#
# Time: 96
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.79725
# Measured active power lpf [kW]: 804.226457026869
# Measured reactive power lpf [kVAr]: 493.1410111512887
# Measured apparent power lpf [kVA]: 943.3812861517372
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 97
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.897125
# Measured active power lpf [kW]: 804.0422501358288
# Measured reactive power lpf [kVAr]: 493.1234910962485
# Measured apparent power lpf [kVA]: 943.2150960806546
# Discharge
# Discharge power [kW]: 13.317279931046397
#
# Time: 97
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.797125
# Measured active power lpf [kW]: 804.0422501358288
# Measured reactive power lpf [kVAr]: 493.1234910962485
# Measured apparent power lpf [kVA]: 943.2150960806546
# Discharge
# Discharge power [kW]: 13.317279931046397
#
# Time: 97
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.797125
# Measured active power lpf [kW]: 804.0422501358288
# Measured reactive power lpf [kVAr]: 493.1234910962485
# Measured apparent power lpf [kVA]: 943.2150960806546
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 98
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8969972222222222
# Measured active power lpf [kW]: 803.868417426398
# Measured reactive power lpf [kVAr]: 493.1153769822634
# Measured apparent power lpf [kVA]: 943.0626742438603
# Discharge
# Discharge power [kW]: 13.883237771473954
#
# Time: 98
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7969972222222222
# Measured active power lpf [kW]: 803.868417426398
# Measured reactive power lpf [kVAr]: 493.1153769822634
# Measured apparent power lpf [kVA]: 943.0626742438603
# Discharge
# Discharge power [kW]: 13.883237771473954
#
# Time: 98
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7969972222222222
# Measured active power lpf [kW]: 803.868417426398
# Measured reactive power lpf [kVAr]: 493.1153769822634
# Measured apparent power lpf [kVA]: 943.0626742438603
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 99
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8968666666666667
# Measured active power lpf [kW]: 803.6756983261588
# Measured reactive power lpf [kVAr]: 493.09374465298055
# Measured apparent power lpf [kVA]: 942.8870924431715
# Discharge
# Discharge power [kW]: 13.855964105310376
#
# Time: 99
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7968666666666666
# Measured active power lpf [kW]: 803.6756983261588
# Measured reactive power lpf [kVAr]: 493.09374465298055
# Measured apparent power lpf [kVA]: 942.8870924431715
# Discharge
# Discharge power [kW]: 13.855964105310376
#
# Time: 99
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7968666666666666
# Measured active power lpf [kW]: 803.6756983261588
# Measured reactive power lpf [kVAr]: 493.09374465298055
# Measured apparent power lpf [kVA]: 942.8870924431715
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 100
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8967333333333334
# Measured active power lpf [kW]: 803.4790314922824
# Measured reactive power lpf [kVAr]: 493.0699519660898
# Measured apparent power lpf [kVA]: 942.7070231941726
# Discharge
# Discharge power [kW]: 14.419994754735542
#
# Time: 100
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7967333333333333
# Measured active power lpf [kW]: 803.4790314922824
# Measured reactive power lpf [kVAr]: 493.0699519660898
# Measured apparent power lpf [kVA]: 942.7070231941726
# Discharge
# Discharge power [kW]: 14.419994754735542
#
# Time: 100
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7967333333333333
# Measured active power lpf [kW]: 803.4790314922824
# Measured reactive power lpf [kVAr]: 493.0699519660898
# Measured apparent power lpf [kVA]: 942.7070231941726
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 101
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8965972222222223
# Measured active power lpf [kW]: 803.2617037662925
# Measured reactive power lpf [kVAr]: 493.03232271936423
# Measured apparent power lpf [kVA]: 942.5021145777756
# Discharge
# Discharge power [kW]: 14.3907544202332
#
# Time: 101
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7965972222222222
# Measured active power lpf [kW]: 803.2617037662925
# Measured reactive power lpf [kVAr]: 493.03232271936423
# Measured apparent power lpf [kVA]: 942.5021145777756
# Discharge
# Discharge power [kW]: 14.3907544202332
#
# Time: 101
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7965972222222222
# Measured active power lpf [kW]: 803.2617037662925
# Measured reactive power lpf [kVAr]: 493.03232271936423
# Measured apparent power lpf [kVA]: 942.5021145777756
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 102
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8964583333333334
# Measured active power lpf [kW]: 803.0370599010884
# Measured reactive power lpf [kVAr]: 492.99021153130116
# Measured apparent power lpf [kVA]: 942.2886331906276
# Discharge
# Discharge power [kW]: 14.952611792398468
#
# Time: 102
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7964583333333334
# Measured active power lpf [kW]: 803.0370599010884
# Measured reactive power lpf [kVAr]: 492.99021153130116
# Measured apparent power lpf [kVA]: 942.2886331906276
# Discharge
# Discharge power [kW]: 14.952611792398468
#
# Time: 102
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7964583333333334
# Measured active power lpf [kW]: 803.0370599010884
# Measured reactive power lpf [kVAr]: 492.99021153130116
# Measured apparent power lpf [kVA]: 942.2886331906276
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 103
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8963166666666667
# Measured active power lpf [kW]: 802.8386193654018
# Measured reactive power lpf [kVAr]: 492.96753498673957
# Measured apparent power lpf [kVA]: 942.107658017621
# Discharge
# Discharge power [kW]: 14.921125019244084
#
# Time: 103
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7963166666666667
# Measured active power lpf [kW]: 802.8386193654018
# Measured reactive power lpf [kVAr]: 492.96753498673957
# Measured apparent power lpf [kVA]: 942.107658017621
# Discharge
# Discharge power [kW]: 14.921125019244084
#
# Time: 103
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7963166666666667
# Measured active power lpf [kW]: 802.8386193654018
# Measured reactive power lpf [kVAr]: 492.96753498673957
# Measured apparent power lpf [kVA]: 942.107658017621
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 104
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8961722222222223
# Measured active power lpf [kW]: 802.6583184731687
# Measured reactive power lpf [kVAr]: 492.9592844209994
# Measured apparent power lpf [kVA]: 941.9496973358176
# Discharge
# Discharge power [kW]: 15.480997986052486
#
# Time: 104
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7961722222222222
# Measured active power lpf [kW]: 802.6583184731687
# Measured reactive power lpf [kVAr]: 492.9592844209994
# Measured apparent power lpf [kVA]: 941.9496973358176
# Discharge
# Discharge power [kW]: 15.480997986052486
#
# Time: 104
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7961722222222222
# Measured active power lpf [kW]: 802.6583184731687
# Measured reactive power lpf [kVAr]: 492.9592844209994
# Measured apparent power lpf [kVA]: 941.9496973358176
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 105
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.896025
# Measured active power lpf [kW]: 802.4431744033568
# Measured reactive power lpf [kVAr]: 492.9262001091323
# Measured apparent power lpf [kVA]: 941.7490572867936
# Discharge
# Discharge power [kW]: 15.44770820397577
#
# Time: 105
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.796025
# Measured active power lpf [kW]: 802.4431744033568
# Measured reactive power lpf [kVAr]: 492.9262001091323
# Measured apparent power lpf [kVA]: 941.7490572867936
# Discharge
# Discharge power [kW]: 15.44770820397577
#
# Time: 105
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.796025
# Measured active power lpf [kW]: 802.4431744033568
# Measured reactive power lpf [kVAr]: 492.9262001091323
# Measured apparent power lpf [kVA]: 941.7490572867936
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 106
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.895875
# Measured active power lpf [kW]: 802.1769948283686
# Measured reactive power lpf [kVAr]: 492.8556812012926
# Measured apparent power lpf [kVA]: 941.4853442960558
# Discharge
# Discharge power [kW]: 16.005429730086053
#
# Time: 106
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.795875
# Measured active power lpf [kW]: 802.1769948283686
# Measured reactive power lpf [kVAr]: 492.8556812012926
# Measured apparent power lpf [kVA]: 941.4853442960558
# Discharge
# Discharge power [kW]: 16.005429730086053
#
# Time: 106
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.795875
# Measured active power lpf [kW]: 802.1769948283686
# Measured reactive power lpf [kVAr]: 492.8556812012926
# Measured apparent power lpf [kVA]: 941.4853442960558
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 107
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8957222222222222
# Measured active power lpf [kW]: 801.90566596283
# Measured reactive power lpf [kVAr]: 492.78201651020305
# Measured apparent power lpf [kVA]: 941.21560383323
# Discharge
# Discharge power [kW]: 15.969478152259455
#
# Time: 107
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7957222222222222
# Measured active power lpf [kW]: 801.90566596283
# Measured reactive power lpf [kVAr]: 492.78201651020305
# Measured apparent power lpf [kVA]: 941.21560383323
# Discharge
# Discharge power [kW]: 15.969478152259455
#
# Time: 107
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7957222222222222
# Measured active power lpf [kW]: 801.90566596283
# Measured reactive power lpf [kVAr]: 492.78201651020305
# Measured apparent power lpf [kVA]: 941.21560383323
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 108
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8955666666666666
# Measured active power lpf [kW]: 801.5930657031286
# Measured reactive power lpf [kVAr]: 492.6787748880951
# Measured apparent power lpf [kVA]: 940.8952216950485
# Discharge
# Discharge power [kW]: 16.524486389714355
#
# Time: 108
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7955666666666666
# Measured active power lpf [kW]: 801.5930657031286
# Measured reactive power lpf [kVAr]: 492.6787748880951
# Measured apparent power lpf [kVA]: 940.8952216950485
# Discharge
# Discharge power [kW]: 16.524486389714355
#
# ...
# Measured apparent power lpf [kVA]: 897.230293974956
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1780
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4706915601307718
# Measured active power lpf [kW]: 766.2487850174994
# Measured reactive power lpf [kVAr]: 466.78153335965646
# Measured apparent power lpf [kVA]: 897.230293974956
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1781
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.3336360497125
# Measured reactive power lpf [kVAr]: 466.84430966109664
# Measured apparent power lpf [kVA]: 897.3354173351897
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1781
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.3336360497125
# Measured reactive power lpf [kVAr]: 466.84430966109664
# Measured apparent power lpf [kVA]: 897.3354173351897
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1781
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.47041378235299397
# Measured active power lpf [kW]: 766.3336360497125
# Measured reactive power lpf [kVAr]: 466.84430966109664
# Measured apparent power lpf [kVA]: 897.3354173351897
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1782
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.4060238644801
# Measured reactive power lpf [kVAr]: 466.8967631675371
# Measured apparent power lpf [kVA]: 897.4245265603594
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1782
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.4060238644801
# Measured reactive power lpf [kVAr]: 466.8967631675371
# Measured apparent power lpf [kVA]: 897.4245265603594
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1782
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4701360045752162
# Measured active power lpf [kW]: 766.4060238644801
# Measured reactive power lpf [kVAr]: 466.8967631675371
# Measured apparent power lpf [kVA]: 897.4245265603594
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1783
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.5016373387127
# Measured reactive power lpf [kVAr]: 466.9663517903424
# Measured apparent power lpf [kVA]: 897.5423854878995
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1783
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.5016373387127
# Measured reactive power lpf [kVAr]: 466.9663517903424
# Measured apparent power lpf [kVA]: 897.5423854878995
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1783
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.46985822679743844
# Measured active power lpf [kW]: 766.5016373387127
# Measured reactive power lpf [kVAr]: 466.9663517903424
# Measured apparent power lpf [kVA]: 897.5423854878995
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1784
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.5858990955088
# Measured reactive power lpf [kVAr]: 467.0283199283132
# Measured apparent power lpf [kVA]: 897.6465854149575
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1784
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.5858990955088
# Measured reactive power lpf [kVAr]: 467.0283199283132
# Measured apparent power lpf [kVA]: 897.6465854149575
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1784
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4695804490196607
# Measured active power lpf [kW]: 766.5858990955088
# Measured reactive power lpf [kVAr]: 467.0283199283132
# Measured apparent power lpf [kVA]: 897.6465854149575
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1785
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.662730578821
# Measured reactive power lpf [kVAr]: 467.0845839127127
# Measured apparent power lpf [kVA]: 897.7414722443682
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1785
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.662730578821
# Measured reactive power lpf [kVAr]: 467.0845839127127
# Measured apparent power lpf [kVA]: 897.7414722443682
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1785
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.46930267124188285
# Measured active power lpf [kW]: 766.662730578821
# Measured reactive power lpf [kVAr]: 467.0845839127127
# Measured apparent power lpf [kVA]: 897.7414722443682
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1786
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.7673502674141
# Measured reactive power lpf [kVAr]: 467.1614472041561
# Measured apparent power lpf [kVA]: 897.8708076276858
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1786
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.7673502674141
# Measured reactive power lpf [kVAr]: 467.1614472041561
# Measured apparent power lpf [kVA]: 897.8708076276858
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1786
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4690248934641051
# Measured active power lpf [kW]: 766.7673502674141
# Measured reactive power lpf [kVAr]: 467.1614472041561
# Measured apparent power lpf [kVA]: 897.8708076276858
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1787
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.8634720293857
# Measured reactive power lpf [kVAr]: 467.2312454427029
# Measured apparent power lpf [kVA]: 897.9892100971501
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1787
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.8634720293857
# Measured reactive power lpf [kVAr]: 467.2312454427029
# Measured apparent power lpf [kVA]: 897.9892100971501
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1787
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4687471156863273
# Measured active power lpf [kW]: 766.8634720293857
# Measured reactive power lpf [kVAr]: 467.2312454427029
# Measured apparent power lpf [kVA]: 897.9892100971501
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1788
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.9472836497577
# Measured reactive power lpf [kVAr]: 467.2915728223521
# Measured apparent power lpf [kVA]: 898.0921722899768
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1788
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.9472836497577
# Measured reactive power lpf [kVAr]: 467.2915728223521
# Measured apparent power lpf [kVA]: 898.0921722899768
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1788
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.46846933790854955
# Measured active power lpf [kW]: 766.9472836497577
# Measured reactive power lpf [kVAr]: 467.2915728223521
# Measured apparent power lpf [kVA]: 898.0921722899768
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1789
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.0273736592032
# Measured reactive power lpf [kVAr]: 467.3488359806436
# Measured apparent power lpf [kVA]: 898.190362025221
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1789
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.0273736592032
# Measured reactive power lpf [kVAr]: 467.3488359806436
# Measured apparent power lpf [kVA]: 898.190362025221
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1789
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4681915601307718
# Measured active power lpf [kW]: 767.0273736592032
# Measured reactive power lpf [kVAr]: 467.3488359806436
# Measured apparent power lpf [kVA]: 898.190362025221
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1790
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.1136117817705
# Measured reactive power lpf [kVAr]: 467.41050560574195
# Measured apparent power lpf [kVA]: 898.2960949105191
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1790
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.1136117817705
# Measured reactive power lpf [kVAr]: 467.41050560574195
# Measured apparent power lpf [kVA]: 898.2960949105191
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1790
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.46791378235299397
# Measured active power lpf [kW]: 767.1136117817705
# Measured reactive power lpf [kVAr]: 467.41050560574195
# Measured apparent power lpf [kVA]: 898.2960949105191
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1791
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.2271687436578
# Measured reactive power lpf [kVAr]: 467.4922073314529
# Measured apparent power lpf [kVA]: 898.4355805365475
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1791
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.2271687436578
# Measured reactive power lpf [kVAr]: 467.4922073314529
# Measured apparent power lpf [kVA]: 898.4355805365475
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1791
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4676360045752162
# Measured active power lpf [kW]: 767.2271687436578
# Measured reactive power lpf [kVAr]: 467.4922073314529
# Measured apparent power lpf [kVA]: 898.4355805365475
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1792
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.3452313881722
# Measured reactive power lpf [kVAr]: 467.5777341864386
# Measured apparent power lpf [kVA]: 898.5809043381076
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1792
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.3452313881722
# Measured reactive power lpf [kVAr]: 467.5777341864386
# Measured apparent power lpf [kVA]: 898.5809043381076
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1792
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.46735822679743844
# Measured active power lpf [kW]: 767.3452313881722
# Measured reactive power lpf [kVAr]: 467.5777341864386
# Measured apparent power lpf [kVA]: 898.5809043381076
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1793
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.428008398159
# Measured reactive power lpf [kVAr]: 467.6371258660058
# Measured apparent power lpf [kVA]: 898.6824965259885
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1793
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.428008398159
# Measured reactive power lpf [kVAr]: 467.6371258660058
# Measured apparent power lpf [kVA]: 898.6824965259885
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1793
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.46708044901966067
# Measured active power lpf [kW]: 767.428008398159
# Measured reactive power lpf [kVAr]: 467.6371258660058
# Measured apparent power lpf [kVA]: 898.6824965259885
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1794
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.475630443926
# Measured reactive power lpf [kVAr]: 467.67038121504606
# Measured apparent power lpf [kVA]: 898.7404679834597
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1794
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.475630443926
# Measured reactive power lpf [kVAr]: 467.67038121504606
# Measured apparent power lpf [kVA]: 898.7404679834597
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1794
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4668026712418829
# Measured active power lpf [kW]: 767.475630443926
# Measured reactive power lpf [kVAr]: 467.67038121504606
# Measured apparent power lpf [kVA]: 898.7404679834597
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1795
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4845485157265
# Measured reactive power lpf [kVAr]: 467.67579198932606
# Measured apparent power lpf [kVA]: 898.7508990945332
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1795
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4845485157265
# Measured reactive power lpf [kVAr]: 467.67579198932606
# Measured apparent power lpf [kVA]: 898.7508990945332
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1795
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4665248934641051
# Measured active power lpf [kW]: 767.4845485157265
# Measured reactive power lpf [kVAr]: 467.67579198932606
# Measured apparent power lpf [kVA]: 898.7508990945332
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1796
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4918519325557
# Measured reactive power lpf [kVAr]: 467.6800406847558
# Measured apparent power lpf [kVA]: 898.7593466761605
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1796
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4918519325557
# Measured reactive power lpf [kVAr]: 467.6800406847558
# Measured apparent power lpf [kVA]: 898.7593466761605
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1796
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4662471156863273
# Measured active power lpf [kW]: 767.4918519325557
# Measured reactive power lpf [kVAr]: 467.6800406847558
# Measured apparent power lpf [kVA]: 898.7593466761605
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1797
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.461850339431
# Measured reactive power lpf [kVAr]: 467.6564700314193
# Measured apparent power lpf [kVA]: 898.7214616824675
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1797
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.461850339431
# Measured reactive power lpf [kVAr]: 467.6564700314193
# Measured apparent power lpf [kVA]: 898.7214616824675
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1797
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.46596933790854955
# Measured active power lpf [kW]: 767.461850339431
# Measured reactive power lpf [kVAr]: 467.6564700314193
# Measured apparent power lpf [kVA]: 898.7214616824675
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1798
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4224127528171
# Measured reactive power lpf [kVAr]: 467.62563562812664
# Measured apparent power lpf [kVA]: 898.6717391194433
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1798
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4224127528171
# Measured reactive power lpf [kVAr]: 467.62563562812664
# Measured apparent power lpf [kVA]: 898.6717391194433
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1798
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4656915601307718
# Measured active power lpf [kW]: 767.4224127528171
# Measured reactive power lpf [kVAr]: 467.62563562812664
# Measured apparent power lpf [kVA]: 898.6717391194433
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1799
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.3589648136384
# Measured reactive power lpf [kVAr]: 467.5772300328655
# Measured apparent power lpf [kVA]: 898.5923697233724
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1799
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.3589648136384
# Measured reactive power lpf [kVAr]: 467.5772300328655
# Measured apparent power lpf [kVA]: 898.5923697233724
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1799
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.46541378235299397
# Measured active power lpf [kW]: 767.3589648136384
# Measured reactive power lpf [kVAr]: 467.5772300328655
# Measured apparent power lpf [kVA]: 898.5923697233724
# Discharge
# Discharge power [kW]: 10.0
#
# Time: 1800
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.2933118822531
# Measured reactive power lpf [kVAr]: 467.5274327228693
# Measured apparent power lpf [kVA]: 898.5103932663626
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1800
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.2933118822531
# Measured reactive power lpf [kVAr]: 467.5274327228693
# Measured apparent power lpf [kVA]: 898.5103932663626
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1800
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.4651360045752162
# Measured active power lpf [kW]: 767.2933118822531
# Measured reactive power lpf [kVAr]: 467.5274327228693
# Measured apparent power lpf [kVA]: 898.5103932663626
# Discharge
# Discharge power [kW]: 10.0
#
# Simulation Complete

# %%
env.k.device.devices['bsd_1']['device'].current_capacity
# Out:
# 7200000.0

# %%
from pycigar.utils.logging import logger

Logger = logger()

Logger.log_dict.keys()
# Out:
# dict_keys(['psc_1', 'psc_2', 'psc_3', 'pv_1', 'bsd_1', 'bsd_2', 'bsd_3', 's701a', 's702a', 's703a', 'network'])

# %%
env.k.device.devices['pv_1']['device']

# %%
# print(Logger.log_dict['bsd_1'].keys())
# print(Logger.log_dict['psc_1'].keys())

# %%
Logger.log_dict['bsd_1'].keys()
# Logger.log_dict['bsd_1']['SOC']

fig1 = plt.figure(figsize = [16, 4])
plt.plot(Logger.log_dict['psc']['p_target'],'--',label="Target Power")
plt.plot(Logger.log_dict['psc']['measured_active_power_lpf'],label="Measured Power")
# plt.plot(Logger.log_dict['psc_1']['p_target'],'--',label="Target Power")
# plt.plot(Logger.log_dict['psc_1']['measured_active_power_lpf'],label="Measured Power")
plt.title('Measured Substation Power')
plt.xlabel('Time [s]')
plt.ylabel('Power [kW]')
plt.legend()

fig1.savefig('/home/michael/Desktop/temp/ieee_03_substation_power.png')


fig1 = plt.figure(figsize = [16, 4])
plt.plot(Logger.log_dict['psc']['p_set'],label="bsd_1_psc p_set")
# plt.plot(Logger.log_dict['psc_1']['p_set'],label="psc_1 p_set")
# plt.plot(Logger.log_dict['psc_2']['p_set'],label="psc_2 p_set")
# plt.plot(Logger.log_dict['psc_3']['p_set'],label="psc_3 p_set")
plt.title('Dist Peak Shaving Controller Setpoints')
plt.xlabel('Time [s]')
plt.ylabel('PSC Setpoints [kW]')
plt.legend()

fig1.savefig('/home/michael/Desktop/temp/ieee_03_setpoint.png')


fig1 = plt.figure(figsize = [16, 4])
plt.plot(np.array(Logger.log_dict['bsd_1']['p_in'])/1e3,label="bsd_1 p_in")
plt.plot(np.array(Logger.log_dict['bsd_1']['p_out'])/1e3,label="bsd_1 p_out")
plt.plot(np.array(Logger.log_dict['bsd_2']['p_in'])/1e3,label="bsd_2 p_in")
plt.plot(np.array(Logger.log_dict['bsd_2']['p_out'])/1e3,label="bsd_2 p_out")
plt.plot(np.array(Logger.log_dict['bsd_3']['p_in'])/1e3,label="bsd_3 p_in")
plt.plot(np.array(Logger.log_dict['bsd_3']['p_out'])/1e3,label="bsd_3 p_out")
# plt.plot(Logger.log_dict['bsd_1_psc']['measured_active_power_lpf'],label="P meas lpf")
plt.title('Battery Power Output')
plt.xlabel('Time [s]')
plt.ylabel('Battery Output [kW]')
plt.legend()

fig1.savefig('/home/michael/Desktop/temp/ieee_03_battery_power.png')


fig1 = plt.figure(figsize = [16, 4])
plt.plot(Logger.log_dict['bsd_1']['SOC'],label="bsd_1 SOC")
plt.plot(Logger.log_dict['bsd_2']['SOC'],label="bsd_2 SOC")
plt.plot(Logger.log_dict['bsd_3']['SOC'],label="bsd_3 SOC")
# plt.plot(Logger.log_dict['bsd_1_psc']['measured_active_power_lpf'],label="P meas lpf")
plt.title('Battery State of Charge')
plt.xlabel('Time [s]')
plt.ylabel('SOC')
plt.legend()

fig1.savefig('/home/michael/Desktop/temp/ieee_03_battery_soc.png')

plt.show()

# fig1.savefig('/home/michael/Desktop/temp/SOC.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-4a1594ba3463> in <module>
#       3
#       4 fig1 = plt.figure(figsize = [16, 4])
# ----> 5 plt.plot(Logger.log_dict['psc']['p_target'],'--',label="Target Power")
#       6 plt.plot(Logger.log_dict['psc']['measured_active_power_lpf'],label="Measured Power")
#       7 # plt.plot(Logger.log_dict['psc_1']['p_target'],'--',label="Target Power")
#
# KeyError: 'psc'
