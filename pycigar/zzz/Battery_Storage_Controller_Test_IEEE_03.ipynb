# %%
from pycigar.envs import Env
import yaml

import numpy as np
from scipy import signal
import math
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 6]

class FooEnv(Env):
    @property
    def observation_space(self):
        return Box(low=-float('inf'), high=float('inf'),
                   shape=(5,), dtype=np.float64)

    @property
    def action_space(self):
        return Box(low=0.5, high=1.5, shape=(5,), dtype=np.float64)

    def step(self, rl_actions=None, randomize_rl_update=None):
        """See parent class.
        """

        for _ in range(self.sim_params['env_config']["sims_per_step"]):
            self.env_time += 1
            
            # perform action update for PV inverter device
            if len(self.k.device.group_controllers.keys()) > 0:
                control_setting = []
                devices = []
                for group_controller_name, group_controller in self.k.device.group_controllers.items():
                    action = group_controller.get_action(self)
                    if isinstance(action, tuple):
                        if isinstance(group_controller.device_id, str):
                            devices.extend([group_controller.device_id])
                            control_setting.extend((action,))
                        else:
                            devices.extend(group_controller.device_id)
                            control_setting.extend((action,)*len(group_controller.device_id))
                    elif isinstance(action, dict):
                        devices.extend(action.keys())
                        control_setting.extend(action.values())
                self.k.device.apply_control(devices, control_setting)

            # perform action update for PV inverter device
            if len(self.k.device.get_local_device_ids()) > 0:
                control_setting = []
                for device_id in self.k.device.get_local_device_ids():
                    action = self.k.device.get_controller(device_id).get_action(self)
                    control_setting.append(action)
                self.k.device.apply_control(self.k.device.get_local_device_ids(), control_setting)


            self.additional_command()

            if self.k.time <= self.k.t:
                self.k.update(reset=False)

                # check whether the simulator sucessfully solved the powerflow
                converged = self.k.simulation.check_converged()
                if not converged:
                    break

            if self.k.time >= self.k.t:
                break

        # the episode will be finished if it is not converged.
        done = not converged or (self.k.time == self.k.t)
        obs = self.get_state()
        infos = {}
        reward = self.compute_reward(rl_actions)

        return obs, reward, done, infos

    def get_state(self):
        return [0, 0, 0, 0, 0]

    def compute_reward(self, rl_actions, **kwargs):
        return 0

stream = open("./IEEE_03_Node/pycigar_config_ieee_03_dist.yaml", "r")
sim_params = yaml.safe_load(stream)

print('Simulation Complete')
# Out:
# Simulation Complete

# %%
from pycigar.utils.registry import register_devcon
from pycigar.controllers.battery_storage_controller import BatteryStorageController
from pycigar.devices.battery_storage_device import BatteryStorageDevice
from pycigar.devices.battery_storage_device_advanced import BatteryStorageDeviceAdvanced

# from pycigar.controllers.battery_peak_shaving_controller import BatteryPeakShavingController
from pycigar.controllers.battery_peak_shaving_controller_dist import BatteryPeakShavingControllerDist
from pycigar.controllers.battery_peak_shaving_controller_cent import BatteryPeakShavingControllerCent

# register_devcon('battery_storage_controller', BatteryStorageController)
# register_devcon('battery_peak_shaving_controller', BatteryPeakShavingController)
register_devcon('battery_peak_shaving_controller_dist', BatteryPeakShavingControllerDist)
register_devcon('battery_peak_shaving_controller_cent', BatteryPeakShavingControllerCent)
register_devcon('battery_storage_device_advanced', BatteryStorageDeviceAdvanced)
# Out:
# 'battery_storage_device_advanced'

# %%
sim_params
# Out:
# {'is_disable_log': False,
#  'is_disable_y': False,
#  'vectorized_mode': False,
#  'env_config': {'clip_actions': 'True,', 'sims_per_step': 20},
#  'simulation_config': {'network_model_directory': '/home/michael/Desktop/git/ceds-cigar/pycigar/zzz/IEEE_03_Node/ieee3.dss',
#   'custom_configs': {'solution_mode': 1,
#    'solution_number': 1,
#    'solution_step_size': 1,
#    'solution_control_mode': -1,
#    'solution_max_control_iterations': 1000000,
#    'solution_max_iterations': 30000,
#    'power_factor': 0.9}},
#  'scenario_config': {'network_data_directory': '/home/michael/Desktop/git/ceds-cigar/pycigar/zzz/IEEE_03_Node/load_solar_data.csv',
#   'multi_config': False,
#   'start_end_time': [3600, 5401],
#   'custom_configs': {'load_scaling_factor': 1.25,
#    'solar_scaling_factor': 0,
#    'slack_bus_voltage': 1.04,
#    'load_generation_noise': False,
#    'power_factor': 0.9},
#   'nodes': [{'name': 's701a',
#     'devices': [{'name': 'pv_1',
#       'device': 'pv_device',
#       'custom_device_configs': {'default_control_setting': [0.98,
#         1.01,
#         1.01,
#         1.04,
#         1.06],
#        'gain': '1e5',
#        'low_pass_filter_measure_mean': 1.2,
#        'low_pass_filter_output_mean': 0.115},
#       'controller': 'fixed_controller',
#       'custom_controller_configs': {'default_control_setting': [0.98,
#         1.01,
#         1.01,
#         1.04,
#         1.06]}},
#      {'name': 'bsd_1',
#       'device': 'battery_storage_device_advanced',
#       'custom_device_configs': {'default_control_setting': 'standby',
#        'total_capacity': 10,
#        'current_capacity': 9.0,
#        'max_charge_power': 20.0,
#        'max_discharge_power': 25.0,
#        'max_ramp_rate': 0.1,
#        'max_SOC': 1.0,
#        'min_SOC': 0.2}}]},
#    {'name': 's702a',
#     'devices': [{'name': 'bsd_2',
#       'device': 'battery_storage_device_advanced',
#       'custom_device_configs': {'default_control_setting': 'standby',
#        'total_capacity': 10,
#        'current_capacity': 8.0,
#        'max_charge_power': 20.0,
#        'max_discharge_power': 30.0,
#        'max_ramp_rate': 0.1,
#        'max_SOC': 1.0,
#        'min_SOC': 0.2}}]},
#    {'name': 's703a',
#     'devices': [{'name': 'bsd_3',
#       'device': 'battery_storage_device_advanced',
#       'custom_device_configs': {'default_control_setting': 'standby',
#        'total_capacity': 10,
#        'current_capacity': 8.0,
#        'max_charge_power': 5.0,
#        'max_discharge_power': 10.0,
#        'max_ramp_rate': 0.1,
#        'max_SOC': 1.0,
#        'min_SOC': 0.2}}]}],
#   'controllers': [{'name': 'psc_1',
#     'controller': 'battery_peak_shaving_controller_dist',
#     'custom_controller_configs': {'default_control_setting': 'standby',
#      'lowpass_filter_frequency': 0.01,
#      'active_power_target': 750,
#      'eta': 0.01},
#     'list_devices': ['bsd_1']},
#    {'name': 'psc_2',
#     'controller': 'battery_peak_shaving_controller_dist',
#     'custom_controller_configs': {'default_control_setting': 'standby',
#      'lowpass_filter_frequency': 0.01,
#      'active_power_target': 750,
#      'eta': 0.01},
#     'list_devices': ['bsd_2']},
#    {'name': 'psc_3',
#     'controller': 'battery_peak_shaving_controller_dist',
#     'custom_controller_configs': {'default_control_setting': 'standby',
#      'lowpass_filter_frequency': 0.01,
#      'active_power_target': 750,
#      'eta': 0.01},
#     'list_devices': ['bsd_3']}]}}

# %%
env = FooEnv(sim_params)
env.reset()
done = False
while not done:
    _, _, done, _ = env.step()
    # if env.k.time % 60 == 0:
    #     print('Time: ' + str(env.k.time))
    # if env.k.time >= 55:
    #     done = True
    
print('Simulation Complete')
# Out:
# psc_1
# psc_2
# psc_3
# bsd_1
# 32400000.0
# bsd_2
# 28800000.0
# bsd_3
# 28800000.0
# bsd_1
# 32400000.0
# bsd_2
# 28800000.0
# bsd_3
# 28800000.0
# Time: 51
# Initialize: bsd_1
# Time: 51
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.9
# Measured active power lpf [kW]: 809.2184386867442
# Measured reactive power lpf [kVAr]: 493.58042594805687
# Measured apparent power lpf [kVA]: 947.869251737642
#
# Time: 51
# Initialize: bsd_2
# Time: 51
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.8
# Measured active power lpf [kW]: 809.2184386867442
# Measured reactive power lpf [kVAr]: 493.58042594805687
# Measured apparent power lpf [kVA]: 947.869251737642
#
# Time: 51
# Initialize: bsd_3
# Time: 51
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.8
# Measured active power lpf [kW]: 809.2184386867442
# Measured reactive power lpf [kVAr]: 493.58042594805687
# Measured apparent power lpf [kVA]: 947.869251737642
#
# Time: 52
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.9
# Measured active power lpf [kW]: 809.2249846743092
# Measured reactive power lpf [kVAr]: 493.58441830756243
# Measured apparent power lpf [kVA]: 947.8769191288238
# Discharge
# Discharge power [kW]: 5.922498467430922
#
# Time: 52
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.8
# Measured active power lpf [kW]: 809.2249846743092
# Measured reactive power lpf [kVAr]: 493.58441830756243
# Measured apparent power lpf [kVA]: 947.8769191288238
# Discharge
# Discharge power [kW]: 5.922498467430922
#
# Time: 52
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.8
# Measured active power lpf [kW]: 809.2249846743092
# Measured reactive power lpf [kVAr]: 493.58441830756243
# Measured apparent power lpf [kVA]: 947.8769191288238
# Discharge
# Discharge power [kW]: 5.922498467430922
#
# test01
# test01
# test01
# Time: 53
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999972222222222
# Measured active power lpf [kW]: 809.2245362278546
# Measured reactive power lpf [kVAr]: 493.58855279079427
# Measured apparent power lpf [kVA]: 947.8786892209873
# Discharge
# Discharge power [kW]: 6.5147034695285555
#
# Time: 53
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999972222222222
# Measured active power lpf [kW]: 809.2245362278546
# Measured reactive power lpf [kVAr]: 493.58855279079427
# Measured apparent power lpf [kVA]: 947.8786892209873
# Discharge
# Discharge power [kW]: 6.5147034695285555
#
# Time: 53
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999972222222222
# Measured active power lpf [kW]: 809.2245362278546
# Measured reactive power lpf [kVAr]: 493.58855279079427
# Measured apparent power lpf [kVA]: 947.8786892209873
# Discharge
# Discharge power [kW]: 6.5147034695285555
#
# test01
# test01
# test01
# Time: 54
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999916666666666
# Measured active power lpf [kW]: 809.2438317468608
# Measured reactive power lpf [kVAr]: 493.6133400898469
# Measured apparent power lpf [kVA]: 947.9080697699521
# Discharge
# Discharge power [kW]: 6.5166285369646255
#
# Time: 54
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999916666666667
# Measured active power lpf [kW]: 809.2438317468608
# Measured reactive power lpf [kVAr]: 493.6133400898469
# Measured apparent power lpf [kVA]: 947.9080697699521
# Discharge
# Discharge power [kW]: 6.5166285369646255
#
# Time: 54
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999916666666667
# Measured active power lpf [kW]: 809.2438317468608
# Measured reactive power lpf [kVAr]: 493.6133400898469
# Measured apparent power lpf [kVA]: 947.9080697699521
# Discharge
# Discharge power [kW]: 6.5166285369646255
#
# test01
# test01
# test01
# Time: 55
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999833333333334
# Measured active power lpf [kW]: 809.3313671224971
# Measured reactive power lpf [kVAr]: 493.69577208598923
# Measured apparent power lpf [kVA]: 948.0257260137782
# Discharge
# Discharge power [kW]: 7.117824876461412
#
# Time: 55
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999833333333334
# Measured active power lpf [kW]: 809.3313671224971
# Measured reactive power lpf [kVAr]: 493.69577208598923
# Measured apparent power lpf [kVA]: 948.0257260137782
# Discharge
# Discharge power [kW]: 7.117824876461412
#
# Time: 55
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999833333333334
# Measured active power lpf [kW]: 809.3313671224971
# Measured reactive power lpf [kVAr]: 493.69577208598923
# Measured apparent power lpf [kVA]: 948.0257260137782
# Discharge
# Discharge power [kW]: 7.117824876461412
#
# test01
# test01
# test01
# Time: 56
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999722222222222
# Measured active power lpf [kW]: 809.4139587383615
# Measured reactive power lpf [kVAr]: 493.77897162922983
# Measured apparent power lpf [kVA]: 948.1395622078671
# Discharge
# Discharge power [kW]: 7.126954907339672
#
# Time: 56
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999722222222222
# Measured active power lpf [kW]: 809.4139587383615
# Measured reactive power lpf [kVAr]: 493.77897162922983
# Measured apparent power lpf [kVA]: 948.1395622078671
# Discharge
# Discharge power [kW]: 7.126954907339672
#
# Time: 56
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999722222222222
# Measured active power lpf [kW]: 809.4139587383615
# Measured reactive power lpf [kVAr]: 493.77897162922983
# Measured apparent power lpf [kVA]: 948.1395622078671
# Discharge
# Discharge power [kW]: 7.126954907339672
#
# test01
# test01
# test01
# Time: 57
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999583333333333
# Measured active power lpf [kW]: 809.4803060588993
# Measured reactive power lpf [kVAr]: 493.8542878294844
# Measured apparent power lpf [kVA]: 948.2354262021519
# Discharge
# Discharge power [kW]: 7.726858357485241
#
# Time: 57
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999583333333333
# Measured active power lpf [kW]: 809.4803060588993
# Measured reactive power lpf [kVAr]: 493.8542878294844
# Measured apparent power lpf [kVA]: 948.2354262021519
# Discharge
# Discharge power [kW]: 7.726858357485241
#
# Time: 57
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999583333333333
# Measured active power lpf [kW]: 809.4803060588993
# Measured reactive power lpf [kVAr]: 493.8542878294844
# Measured apparent power lpf [kVA]: 948.2354262021519
# Discharge
# Discharge power [kW]: 7.726858357485241
#
# test01
# test01
# test01
# Time: 58
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999416666666666
# Measured active power lpf [kW]: 809.521528204912
# Measured reactive power lpf [kVAr]: 493.9153579207648
# Measured apparent power lpf [kVA]: 948.3024229733958
# Discharge
# Discharge power [kW]: 7.732514914583709
#
# Time: 58
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999416666666667
# Measured active power lpf [kW]: 809.521528204912
# Measured reactive power lpf [kVAr]: 493.9153579207648
# Measured apparent power lpf [kVA]: 948.3024229733958
# Discharge
# Discharge power [kW]: 7.732514914583709
#
# Time: 58
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999416666666667
# Measured active power lpf [kW]: 809.521528204912
# Measured reactive power lpf [kVAr]: 493.9153579207648
# Measured apparent power lpf [kVA]: 948.3024229733958
# Discharge
# Discharge power [kW]: 7.732514914583709
#
# test01
# test01
# test01
# Time: 59
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999222222222222
# Measured active power lpf [kW]: 809.5227590085437
# Measured reactive power lpf [kVAr]: 493.95079619476667
# Measured apparent power lpf [kVA]: 948.3219318428994
# Discharge
# Discharge power [kW]: 8.32631893449881
#
# Time: 59
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999222222222222
# Measured active power lpf [kW]: 809.5227590085437
# Measured reactive power lpf [kVAr]: 493.95079619476667
# Measured apparent power lpf [kVA]: 948.3219318428994
# Discharge
# Discharge power [kW]: 8.32631893449881
#
# Time: 59
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999222222222222
# Measured active power lpf [kW]: 809.5227590085437
# Measured reactive power lpf [kVAr]: 493.95079619476667
# Measured apparent power lpf [kVA]: 948.3219318428994
# Discharge
# Discharge power [kW]: 8.32631893449881
#
# test01
# test01
# test01
# Time: 60
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8999
# Measured active power lpf [kW]: 809.513573632635
# Measured reactive power lpf [kVAr]: 493.9819382958552
# Measured apparent power lpf [kVA]: 948.3303123163414
# Discharge
# Discharge power [kW]: 8.32694704744145
#
# Time: 60
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7999
# Measured active power lpf [kW]: 809.513573632635
# Measured reactive power lpf [kVAr]: 493.9819382958552
# Measured apparent power lpf [kVA]: 948.3303123163414
# Discharge
# Discharge power [kW]: 8.32694704744145
#
# Time: 60
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7999
# Measured active power lpf [kW]: 809.513573632635
# Measured reactive power lpf [kVAr]: 493.9819382958552
# Measured apparent power lpf [kVA]: 948.3303123163414
# Discharge
# Discharge power [kW]: 8.32694704744145
#
# test01
# test01
# test01
# Time: 61
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.899875
# Measured active power lpf [kW]: 809.5122804905159
# Measured reactive power lpf [kVAr]: 494.02270075346325
# Measured apparent power lpf [kVA]: 948.3504421492624
# Discharge
# Discharge power [kW]: 8.920406819022373
#
# Time: 61
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.799875
# Measured active power lpf [kW]: 809.5122804905159
# Measured reactive power lpf [kVAr]: 494.02270075346325
# Measured apparent power lpf [kVA]: 948.3504421492624
# Discharge
# Discharge power [kW]: 8.920406819022373
#
# Time: 61
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.799875
# Measured active power lpf [kW]: 809.5122804905159
# Measured reactive power lpf [kVAr]: 494.02270075346325
# Measured apparent power lpf [kVA]: 948.3504421492624
# Discharge
# Discharge power [kW]: 8.920406819022373
#
# test01
# test01
# test01
# Time: 62
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8998472222222222
# Measured active power lpf [kW]: 809.5025532029216
# Measured reactive power lpf [kVAr]: 494.0603651059784
# Measured apparent power lpf [kVA]: 948.3617600951135
# Discharge
# Discharge power [kW]: 8.920967809375266
#
# Time: 62
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7998472222222223
# Measured active power lpf [kW]: 809.5025532029216
# Measured reactive power lpf [kVAr]: 494.0603651059784
# Measured apparent power lpf [kVA]: 948.3617600951135
# Discharge
# Discharge power [kW]: 8.920967809375266
#
# Time: 62
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7998472222222223
# Measured active power lpf [kW]: 809.5025532029216
# Measured reactive power lpf [kVAr]: 494.0603651059784
# Measured apparent power lpf [kVA]: 948.3617600951135
# Discharge
# Discharge power [kW]: 8.920967809375266
#
# test01
# test01
# test01
# Time: 63
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8998166666666667
# Measured active power lpf [kW]: 809.511746505352
# Measured reactive power lpf [kVAr]: 494.11589670648846
# Measured apparent power lpf [kVA]: 948.398538120026
# Discharge
# Discharge power [kW]: 9.515378952535201
#
# Time: 63
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7998166666666666
# Measured active power lpf [kW]: 809.511746505352
# Measured reactive power lpf [kVAr]: 494.11589670648846
# Measured apparent power lpf [kVA]: 948.398538120026
# Discharge
# Discharge power [kW]: 9.515378952535201
#
# Time: 63
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7998166666666666
# Measured active power lpf [kW]: 809.511746505352
# Measured reactive power lpf [kVAr]: 494.11589670648846
# Measured apparent power lpf [kVA]: 948.398538120026
# Discharge
# Discharge power [kW]: 9.515378952535201
#
# test01
# test01
# test01
# Time: 64
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8997833333333334
# Measured active power lpf [kW]: 809.4932754097875
# Measured reactive power lpf [kVAr]: 494.154047253617
# Measured apparent power lpf [kVA]: 948.4026493798908
# Discharge
# Discharge power [kW]: 9.51515749511538
#
# Time: 64
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7997833333333333
# Measured active power lpf [kW]: 809.4932754097875
# Measured reactive power lpf [kVAr]: 494.154047253617
# Measured apparent power lpf [kVA]: 948.4026493798908
# Discharge
# Discharge power [kW]: 9.51515749511538
#
# Time: 64
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7997833333333333
# Measured active power lpf [kW]: 809.4932754097875
# Measured reactive power lpf [kVAr]: 494.154047253617
# Measured apparent power lpf [kVA]: 948.4026493798908
# Discharge
# Discharge power [kW]: 9.51515749511538
#
# test01
# test01
# test01
# Time: 65
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8997472222222223
# Measured active power lpf [kW]: 809.4568999041622
# Measured reactive power lpf [kVAr]: 494.181745976327
# Measured apparent power lpf [kVA]: 948.386034723555
# Discharge
# Discharge power [kW]: 10.104827046514101
#
# Time: 65
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7997472222222223
# Measured active power lpf [kW]: 809.4568999041622
# Measured reactive power lpf [kVAr]: 494.181745976327
# Measured apparent power lpf [kVA]: 948.386034723555
# Discharge
# Discharge power [kW]: 10.104827046514101
#
# Time: 65
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7997472222222223
# Measured active power lpf [kW]: 809.4568999041622
# Measured reactive power lpf [kVAr]: 494.181745976327
# Measured apparent power lpf [kVA]: 948.386034723555
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 66
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8997083333333333
# Measured active power lpf [kW]: 809.425575140376
# Measured reactive power lpf [kVAr]: 494.2175317980568
# Measured apparent power lpf [kVA]: 948.3779470379369
# Discharge
# Discharge power [kW]: 10.102956467215854
#
# Time: 66
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7997083333333334
# Measured active power lpf [kW]: 809.425575140376
# Measured reactive power lpf [kVAr]: 494.2175317980568
# Measured apparent power lpf [kVA]: 948.3779470379369
# Discharge
# Discharge power [kW]: 10.102956467215854
#
# Time: 66
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7997083333333334
# Measured active power lpf [kW]: 809.425575140376
# Measured reactive power lpf [kVAr]: 494.2175317980568
# Measured apparent power lpf [kVA]: 948.3779470379369
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 67
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8996666666666666
# Measured active power lpf [kW]: 809.3608933661574
# Measured reactive power lpf [kVAr]: 494.2310798685276
# Measured apparent power lpf [kVA]: 948.3298034009451
# Discharge
# Discharge power [kW]: 10.689482144117374
#
# Time: 67
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7996666666666666
# Measured active power lpf [kW]: 809.3608933661574
# Measured reactive power lpf [kVAr]: 494.2310798685276
# Measured apparent power lpf [kVA]: 948.3298034009451
# Discharge
# Discharge power [kW]: 10.689482144117374
#
# Time: 67
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7996666666666666
# Measured active power lpf [kW]: 809.3608933661574
# Measured reactive power lpf [kVAr]: 494.2310798685276
# Measured apparent power lpf [kVA]: 948.3298034009451
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 68
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8996222222222222
# Measured active power lpf [kW]: 809.2630835819423
# Measured reactive power lpf [kVAr]: 494.2221020851876
# Measured apparent power lpf [kVA]: 948.2416488628072
# Discharge
# Discharge power [kW]: 10.680316245034051
#
# Time: 68
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7996222222222222
# Measured active power lpf [kW]: 809.2630835819423
# Measured reactive power lpf [kVAr]: 494.2221020851876
# Measured apparent power lpf [kVA]: 948.2416488628072
# Discharge
# Discharge power [kW]: 10.680316245034051
#
# Time: 68
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7996222222222222
# Measured active power lpf [kW]: 809.2630835819423
# Measured reactive power lpf [kVAr]: 494.2221020851876
# Measured apparent power lpf [kVA]: 948.2416488628072
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 69
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.899575
# Measured active power lpf [kW]: 809.1574509499447
# Measured reactive power lpf [kVAr]: 494.2107609957884
# Measured apparent power lpf [kVA]: 948.1455883522575
# Discharge
# Discharge power [kW]: 11.261768738315535
#
# Time: 69
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.799575
# Measured active power lpf [kW]: 809.1574509499447
# Measured reactive power lpf [kVAr]: 494.2107609957884
# Measured apparent power lpf [kVA]: 948.1455883522575
# Discharge
# Discharge power [kW]: 11.261768738315535
#
# Time: 69
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.799575
# Measured active power lpf [kW]: 809.1574509499447
# Measured reactive power lpf [kVAr]: 494.2107609957884
# Measured apparent power lpf [kVA]: 948.1455883522575
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 70
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.899525
# Measured active power lpf [kW]: 809.0343260010852
# Measured reactive power lpf [kVAr]: 494.1882486017724
# Measured apparent power lpf [kVA]: 948.0287789429799
# Discharge
# Discharge power [kW]: 11.249014996447793
#
# Time: 70
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.799525
# Measured active power lpf [kW]: 809.0343260010852
# Measured reactive power lpf [kVAr]: 494.1882486017724
# Measured apparent power lpf [kVA]: 948.0287789429799
# Discharge
# Discharge power [kW]: 11.249014996447793
#
# Time: 70
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.799525
# Measured active power lpf [kW]: 809.0343260010852
# Measured reactive power lpf [kVAr]: 494.1882486017724
# Measured apparent power lpf [kVA]: 948.0287789429799
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 71
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8994722222222222
# Measured active power lpf [kW]: 808.8988170267452
# Measured reactive power lpf [kVAr]: 494.1577471299954
# Measured apparent power lpf [kVA]: 947.8972387531574
# Discharge
# Discharge power [kW]: 11.82624860600643
#
# Time: 71
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7994722222222223
# Measured active power lpf [kW]: 808.8988170267452
# Measured reactive power lpf [kVAr]: 494.1577471299954
# Measured apparent power lpf [kVA]: 947.8972387531574
# Discharge
# Discharge power [kW]: 11.82624860600643
#
# Time: 71
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7994722222222223
# Measured active power lpf [kW]: 808.8988170267452
# Measured reactive power lpf [kVAr]: 494.1577471299954
# Measured apparent power lpf [kVA]: 947.8972387531574
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 72
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8994166666666666
# Measured active power lpf [kW]: 808.7548880792136
# Measured reactive power lpf [kVAr]: 494.12379469552803
# Measured apparent power lpf [kVA]: 947.7567163973727
# Discharge
# Discharge power [kW]: 11.810059374528084
#
# Time: 72
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7994166666666667
# Measured active power lpf [kW]: 808.7548880792136
# Measured reactive power lpf [kVAr]: 494.12379469552803
# Measured apparent power lpf [kVA]: 947.7567163973727
# Discharge
# Discharge power [kW]: 11.810059374528084
#
# Time: 72
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7994166666666667
# Measured active power lpf [kW]: 808.7548880792136
# Measured reactive power lpf [kVAr]: 494.12379469552803
# Measured apparent power lpf [kVA]: 947.7567163973727
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 73
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8993583333333334
# Measured active power lpf [kW]: 808.6285272726536
# Measured reactive power lpf [kVAr]: 494.10588790024275
# Measured apparent power lpf [kVA]: 947.6395536156286
# Discharge
# Discharge power [kW]: 12.386768511389413
#
# Time: 73
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7993583333333333
# Measured active power lpf [kW]: 808.6285272726536
# Measured reactive power lpf [kVAr]: 494.10588790024275
# Measured apparent power lpf [kVA]: 947.6395536156286
# Discharge
# Discharge power [kW]: 12.386768511389413
#
# Time: 73
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7993583333333333
# Measured active power lpf [kW]: 808.6285272726536
# Measured reactive power lpf [kVAr]: 494.10588790024275
# Measured apparent power lpf [kVA]: 947.6395536156286
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 74
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8992972222222222
# Measured active power lpf [kW]: 808.5114454438777
# Measured reactive power lpf [kVAr]: 494.0979646024502
# Measured apparent power lpf [kVA]: 947.5355170324924
# Discharge
# Discharge power [kW]: 12.372000383721032
#
# Time: 74
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7992972222222222
# Measured active power lpf [kW]: 808.5114454438777
# Measured reactive power lpf [kVAr]: 494.0979646024502
# Measured apparent power lpf [kVA]: 947.5355170324924
# Discharge
# Discharge power [kW]: 12.372000383721032
#
# Time: 74
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7992972222222222
# Measured active power lpf [kW]: 808.5114454438777
# Measured reactive power lpf [kVAr]: 494.0979646024502
# Measured apparent power lpf [kVA]: 947.5355170324924
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 75
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8992333333333333
# Measured active power lpf [kW]: 808.3903516569643
# Measured reactive power lpf [kVAr]: 494.0901324220392
# Measured apparent power lpf [kVA]: 947.4281078841278
# Discharge
# Discharge power [kW]: 12.948065404259257
#
# Time: 75
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7992333333333334
# Measured active power lpf [kW]: 808.3903516569643
# Measured reactive power lpf [kVAr]: 494.0901324220392
# Measured apparent power lpf [kVA]: 947.4281078841278
# Discharge
# Discharge power [kW]: 12.948065404259257
#
# Time: 75
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7992333333333334
# Measured active power lpf [kW]: 808.3903516569643
# Measured reactive power lpf [kVAr]: 494.0901324220392
# Measured apparent power lpf [kVA]: 947.4281078841278
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 76
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8991666666666667
# Measured active power lpf [kW]: 808.2907784991887
# Measured reactive power lpf [kVAr]: 494.10095169853463
# Measured apparent power lpf [kVA]: 947.3487916687403
# Discharge
# Discharge power [kW]: 12.933837205821773
#
# Time: 76
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7991666666666667
# Measured active power lpf [kW]: 808.2907784991887
# Measured reactive power lpf [kVAr]: 494.10095169853463
# Measured apparent power lpf [kVA]: 947.3487916687403
# Discharge
# Discharge power [kW]: 12.933837205821773
#
# Time: 76
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7991666666666667
# Measured active power lpf [kW]: 808.2907784991887
# Measured reactive power lpf [kVAr]: 494.10095169853463
# Measured apparent power lpf [kVA]: 947.3487916687403
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 77
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8990972222222222
# Measured active power lpf [kW]: 808.1615412562138
# Measured reactive power lpf [kVAr]: 494.09128442000264
# Measured apparent power lpf [kVA]: 947.2334844722429
# Discharge
# Discharge power [kW]: 13.508092149176093
#
# Time: 77
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7990972222222222
# Measured active power lpf [kW]: 808.1615412562138
# Measured reactive power lpf [kVAr]: 494.09128442000264
# Measured apparent power lpf [kVA]: 947.2334844722429
# Discharge
# Discharge power [kW]: 13.508092149176093
#
# Time: 77
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7990972222222222
# Measured active power lpf [kW]: 808.1615412562138
# Measured reactive power lpf [kVAr]: 494.09128442000264
# Measured apparent power lpf [kVA]: 947.2334844722429
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 78
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.899025
# Measured active power lpf [kW]: 808.0278326482676
# Measured reactive power lpf [kVAr]: 494.0813156206989
# Measured apparent power lpf [kVA]: 947.1142089419509
# Discharge
# Discharge power [kW]: 13.489158033291798
#
# Time: 78
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.799025
# Measured active power lpf [kW]: 808.0278326482676
# Measured reactive power lpf [kVAr]: 494.0813156206989
# Measured apparent power lpf [kVA]: 947.1142089419509
# Discharge
# Discharge power [kW]: 13.489158033291798
#
# Time: 78
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.799025
# Measured active power lpf [kW]: 808.0278326482676
# Measured reactive power lpf [kVAr]: 494.0813156206989
# Measured apparent power lpf [kVA]: 947.1142089419509
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 79
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.89895
# Measured active power lpf [kW]: 807.9255265665631
# Measured reactive power lpf [kVAr]: 494.0973800556223
# Measured apparent power lpf [kVA]: 947.0353095084091
# Discharge
# Discharge power [kW]: 14.064769006693702
#
# Time: 79
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.79895
# Measured active power lpf [kW]: 807.9255265665631
# Measured reactive power lpf [kVAr]: 494.0973800556223
# Measured apparent power lpf [kVA]: 947.0353095084091
# Discharge
# Discharge power [kW]: 14.064769006693702
#
# Time: 79
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.79895
# Measured active power lpf [kW]: 807.9255265665631
# Measured reactive power lpf [kVAr]: 494.0973800556223
# Measured apparent power lpf [kVA]: 947.0353095084091
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 80
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8988722222222222
# Measured active power lpf [kW]: 807.8020935597804
# Measured reactive power lpf [kVAr]: 494.09935780624784
# Measured apparent power lpf [kVA]: 946.9310417047857
# Discharge
# Discharge power [kW]: 14.045839390108707
#
# Time: 80
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7988722222222222
# Measured active power lpf [kW]: 807.8020935597804
# Measured reactive power lpf [kVAr]: 494.09935780624784
# Measured apparent power lpf [kVA]: 946.9310417047857
# Discharge
# Discharge power [kW]: 14.045839390108707
#
# Time: 80
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7988722222222222
# Measured active power lpf [kW]: 807.8020935597804
# Measured reactive power lpf [kVAr]: 494.09935780624784
# Measured apparent power lpf [kVA]: 946.9310417047857
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 81
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8987916666666667
# Measured active power lpf [kW]: 807.6626202561883
# Measured reactive power lpf [kVAr]: 494.09060873135707
# Measured apparent power lpf [kVA]: 946.8074977499994
# Discharge
# Discharge power [kW]: 14.616499311254028
#
# Time: 81
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7987916666666667
# Measured active power lpf [kW]: 807.6626202561883
# Measured reactive power lpf [kVAr]: 494.09060873135707
# Measured apparent power lpf [kVA]: 946.8074977499994
# Discharge
# Discharge power [kW]: 14.616499311254028
#
# Time: 81
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7987916666666667
# Measured active power lpf [kW]: 807.6626202561883
# Measured reactive power lpf [kVAr]: 494.09060873135707
# Measured apparent power lpf [kVA]: 946.8074977499994
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 82
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8987083333333333
# Measured active power lpf [kW]: 807.4965516904091
# Measured reactive power lpf [kVAr]: 494.0630878437997
# Measured apparent power lpf [kVA]: 946.6514753390773
# Discharge
# Discharge power [kW]: 14.591911405733464
#
# Time: 82
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7987083333333334
# Measured active power lpf [kW]: 807.4965516904091
# Measured reactive power lpf [kVAr]: 494.0630878437997
# Measured apparent power lpf [kVA]: 946.6514753390773
# Discharge
# Discharge power [kW]: 14.591911405733464
#
# Time: 82
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7987083333333334
# Measured active power lpf [kW]: 807.4965516904091
# Measured reactive power lpf [kVAr]: 494.0630878437997
# Measured apparent power lpf [kVA]: 946.6514753390773
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 83
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8986222222222222
# Measured active power lpf [kW]: 807.3056548833217
# Measured reactive power lpf [kVAr]: 494.0179939998439
# Measured apparent power lpf [kVA]: 946.4651070178016
# Discharge
# Discharge power [kW]: 15.155768290871457
#
# Time: 83
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7986222222222222
# Measured active power lpf [kW]: 807.3056548833217
# Measured reactive power lpf [kVAr]: 494.0179939998439
# Measured apparent power lpf [kVA]: 946.4651070178016
# Discharge
# Discharge power [kW]: 15.155768290871457
#
# Time: 83
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7986222222222222
# Measured active power lpf [kW]: 807.3056548833217
# Measured reactive power lpf [kVAr]: 494.0179939998439
# Measured apparent power lpf [kVA]: 946.4651070178016
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 84
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8985333333333333
# Measured active power lpf [kW]: 807.0899579968134
# Measured reactive power lpf [kVAr]: 493.9563099212172
# Measured apparent power lpf [kVA]: 946.2489294103765
# Discharge
# Discharge power [kW]: 15.12430858520711
#
# Time: 84
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7985333333333333
# Measured active power lpf [kW]: 807.0899579968134
# Measured reactive power lpf [kVAr]: 493.9563099212172
# Measured apparent power lpf [kVA]: 946.2489294103765
# Discharge
# Discharge power [kW]: 15.12430858520711
#
# Time: 84
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7985333333333333
# Measured active power lpf [kW]: 807.0899579968134
# Measured reactive power lpf [kVAr]: 493.9563099212172
# Measured apparent power lpf [kVA]: 946.2489294103765
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 85
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8984416666666667
# Measured active power lpf [kW]: 806.8395919511853
# Measured reactive power lpf [kVAr]: 493.8704751821783
# Measured apparent power lpf [kVA]: 945.9905778582712
# Discharge
# Discharge power [kW]: 15.680061577625949
#
# Time: 85
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7984416666666667
# Measured active power lpf [kW]: 806.8395919511853
# Measured reactive power lpf [kVAr]: 493.8704751821783
# Measured apparent power lpf [kVA]: 945.9905778582712
# Discharge
# Discharge power [kW]: 15.680061577625949
#
# Time: 85
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7984416666666667
# Measured active power lpf [kW]: 806.8395919511853
# Measured reactive power lpf [kVAr]: 493.8704751821783
# Measured apparent power lpf [kVA]: 945.9905778582712
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 86
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8983472222222222
# Measured active power lpf [kW]: 806.5748901736525
# Measured reactive power lpf [kVAr]: 493.77574200556757
# Measured apparent power lpf [kVA]: 945.7153572041582
# Discharge
# Discharge power [kW]: 15.641197722402879
#
# Time: 86
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7983472222222222
# Measured active power lpf [kW]: 806.5748901736525
# Measured reactive power lpf [kVAr]: 493.77574200556757
# Measured apparent power lpf [kVA]: 945.7153572041582
# Discharge
# Discharge power [kW]: 15.641197722402879
#
# Time: 86
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7983472222222222
# Measured active power lpf [kW]: 806.5748901736525
# Measured reactive power lpf [kVAr]: 493.77574200556757
# Measured apparent power lpf [kVA]: 945.7153572041582
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 87
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.89825
# Measured active power lpf [kW]: 806.3090290675256
# Measured reactive power lpf [kVAr]: 493.6822800766387
# Measured apparent power lpf [kVA]: 945.4398151217688
# Discharge
# Discharge power [kW]: 16.192754190996503
#
# Time: 87
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.79825
# Measured active power lpf [kW]: 806.3090290675256
# Measured reactive power lpf [kVAr]: 493.6822800766387
# Measured apparent power lpf [kVA]: 945.4398151217688
# Discharge
# Discharge power [kW]: 16.192754190996503
#
# Time: 87
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.79825
# Measured active power lpf [kW]: 806.3090290675256
# Measured reactive power lpf [kVAr]: 493.6822800766387
# Measured apparent power lpf [kVA]: 945.4398151217688
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 88
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.89815
# Measured active power lpf [kW]: 806.0629446696565
# Measured reactive power lpf [kVAr]: 493.60517220515555
# Measured apparent power lpf [kVA]: 945.1896829722588
# Discharge
# Discharge power [kW]: 16.153093462678534
#
# Time: 88
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.79815
# Measured active power lpf [kW]: 806.0629446696565
# Measured reactive power lpf [kVAr]: 493.60517220515555
# Measured apparent power lpf [kVA]: 945.1896829722588
# Discharge
# Discharge power [kW]: 16.153093462678534
#
# Time: 88
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.79815
# Measured active power lpf [kW]: 806.0629446696565
# Measured reactive power lpf [kVAr]: 493.60517220515555
# Measured apparent power lpf [kVA]: 945.1896829722588
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 89
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8980472222222222
# Measured active power lpf [kW]: 805.8098314914328
# Measured reactive power lpf [kVAr]: 493.52451876785784
# Measured apparent power lpf [kVA]: 944.9317092537941
# Discharge
# Discharge power [kW]: 16.70346388008379
#
# Time: 89
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7980472222222222
# Measured active power lpf [kW]: 805.8098314914328
# Measured reactive power lpf [kVAr]: 493.52451876785784
# Measured apparent power lpf [kVA]: 944.9317092537941
# Discharge
# Discharge power [kW]: 16.70346388008379
#
# Time: 89
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7980472222222222
# Measured active power lpf [kW]: 805.8098314914328
# Measured reactive power lpf [kVAr]: 493.52451876785784
# Measured apparent power lpf [kVA]: 944.9317092537941
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 90
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8979416666666666
# Measured active power lpf [kW]: 805.5517382843942
# Measured reactive power lpf [kVAr]: 493.4414601458507
# Measured apparent power lpf [kVA]: 944.6682368132625
# Discharge
# Discharge power [kW]: 16.66007113906663
#
# Time: 90
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7979416666666667
# Measured active power lpf [kW]: 805.5517382843942
# Measured reactive power lpf [kVAr]: 493.4414601458507
# Measured apparent power lpf [kVA]: 944.6682368132625
# Discharge
# Discharge power [kW]: 16.66007113906663
#
# Time: 90
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7979416666666667
# Measured active power lpf [kW]: 805.5517382843942
# Measured reactive power lpf [kVAr]: 493.4414601458507
# Measured apparent power lpf [kVA]: 944.6682368132625
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 91
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8978333333333334
# Measured active power lpf [kW]: 805.3122709848132
# Measured reactive power lpf [kVAr]: 493.37382267194477
# Measured apparent power lpf [kVA]: 944.4287070481523
# Discharge
# Discharge power [kW]: 17.209225212265768
#
# Time: 91
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7978333333333333
# Measured active power lpf [kW]: 805.3122709848132
# Measured reactive power lpf [kVAr]: 493.37382267194477
# Measured apparent power lpf [kVA]: 944.4287070481523
# Discharge
# Discharge power [kW]: 17.209225212265768
#
# Time: 91
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7978333333333333
# Measured active power lpf [kW]: 805.3122709848132
# Measured reactive power lpf [kVAr]: 493.37382267194477
# Measured apparent power lpf [kVA]: 944.4287070481523
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 92
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8977222222222222
# Measured active power lpf [kW]: 805.0822185464639
# Measured reactive power lpf [kVAr]: 493.3147951355655
# Measured apparent power lpf [kVA]: 944.2017081743398
# Discharge
# Discharge power [kW]: 17.166241875121727
#
# Time: 92
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7977222222222222
# Measured active power lpf [kW]: 805.0822185464639
# Measured reactive power lpf [kVAr]: 493.3147951355655
# Measured apparent power lpf [kVA]: 944.2017081743398
# Discharge
# Discharge power [kW]: 17.166241875121727
#
# Time: 92
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7977222222222222
# Measured active power lpf [kW]: 805.0822185464639
# Measured reactive power lpf [kVAr]: 493.3147951355655
# Measured apparent power lpf [kVA]: 944.2017081743398
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 93
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8976083333333333
# Measured active power lpf [kW]: 804.8594977363944
# Measured reactive power lpf [kVAr]: 493.2625002904134
# Measured apparent power lpf [kVA]: 943.9844836061826
# Discharge
# Discharge power [kW]: 17.714770072888527
#
# Time: 93
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7976083333333334
# Measured active power lpf [kW]: 804.8594977363944
# Measured reactive power lpf [kVAr]: 493.2625002904134
# Measured apparent power lpf [kVA]: 943.9844836061826
# Discharge
# Discharge power [kW]: 17.714770072888527
#
# Time: 93
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7976083333333334
# Measured active power lpf [kW]: 804.8594977363944
# Measured reactive power lpf [kVAr]: 493.2625002904134
# Measured apparent power lpf [kVA]: 943.9844836061826
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 94
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8974916666666667
# Measured active power lpf [kW]: 804.6195061528616
# Measured reactive power lpf [kVAr]: 493.1988738766184
# Measured apparent power lpf [kVA]: 943.7466179408748
# Discharge
# Discharge power [kW]: 17.668565613125445
#
# Time: 94
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7974916666666667
# Measured active power lpf [kW]: 804.6195061528616
# Measured reactive power lpf [kVAr]: 493.1988738766184
# Measured apparent power lpf [kVA]: 943.7466179408748
# Discharge
# Discharge power [kW]: 17.668565613125445
#
# Time: 94
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7974916666666667
# Measured active power lpf [kW]: 804.6195061528616
# Measured reactive power lpf [kVAr]: 493.1988738766184
# Measured apparent power lpf [kVA]: 943.7466179408748
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 95
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8973722222222222
# Measured active power lpf [kW]: 804.4015885408944
# Measured reactive power lpf [kVAr]: 493.15282836585556
# Measured apparent power lpf [kVA]: 943.5367654587485
# Discharge
# Discharge power [kW]: 18.215174214867147
#
# Time: 95
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7973722222222223
# Measured active power lpf [kW]: 804.4015885408944
# Measured reactive power lpf [kVAr]: 493.15282836585556
# Measured apparent power lpf [kVA]: 943.5367654587485
# Discharge
# Discharge power [kW]: 18.215174214867147
#
# Time: 95
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7973722222222223
# Measured active power lpf [kW]: 804.4015885408944
# Measured reactive power lpf [kVAr]: 493.15282836585556
# Measured apparent power lpf [kVA]: 943.5367654587485
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 96
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.89725
# Measured active power lpf [kW]: 804.226457026869
# Measured reactive power lpf [kVAr]: 493.1410111512887
# Measured apparent power lpf [kVA]: 943.3812861517372
# Discharge
# Discharge power [kW]: 18.17327658593512
#
# Time: 96
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.79725
# Measured active power lpf [kW]: 804.226457026869
# Measured reactive power lpf [kVAr]: 493.1410111512887
# Measured apparent power lpf [kVA]: 943.3812861517372
# Discharge
# Discharge power [kW]: 18.17327658593512
#
# Time: 96
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.79725
# Measured active power lpf [kW]: 804.226457026869
# Measured reactive power lpf [kVAr]: 493.1410111512887
# Measured apparent power lpf [kVA]: 943.3812861517372
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 97
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.897125
# Measured active power lpf [kW]: 804.0422501358288
# Measured reactive power lpf [kVAr]: 493.1234910962485
# Measured apparent power lpf [kVA]: 943.2150960806546
# Discharge
# Discharge power [kW]: 18.721504944629277
#
# Time: 97
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.797125
# Measured active power lpf [kW]: 804.0422501358288
# Measured reactive power lpf [kVAr]: 493.1234910962485
# Measured apparent power lpf [kVA]: 943.2150960806546
# Discharge
# Discharge power [kW]: 18.721504944629277
#
# Time: 97
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.797125
# Measured active power lpf [kW]: 804.0422501358288
# Measured reactive power lpf [kVAr]: 493.1234910962485
# Measured apparent power lpf [kVA]: 943.2150960806546
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 98
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8969972222222222
# Measured active power lpf [kW]: 803.868417426398
# Measured reactive power lpf [kVAr]: 493.1153769822634
# Measured apparent power lpf [kVA]: 943.0626742438603
# Discharge
# Discharge power [kW]: 18.67789512724631
#
# Time: 98
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7969972222222222
# Measured active power lpf [kW]: 803.868417426398
# Measured reactive power lpf [kVAr]: 493.1153769822634
# Measured apparent power lpf [kVA]: 943.0626742438603
# Discharge
# Discharge power [kW]: 18.67789512724631
#
# Time: 98
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7969972222222222
# Measured active power lpf [kW]: 803.868417426398
# Measured reactive power lpf [kVAr]: 493.1153769822634
# Measured apparent power lpf [kVA]: 943.0626742438603
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 99
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8968666666666667
# Measured active power lpf [kW]: 803.6756983261588
# Measured reactive power lpf [kVAr]: 493.09374465298055
# Measured apparent power lpf [kVA]: 942.8870924431715
# Discharge
# Discharge power [kW]: 19.223533937926256
#
# Time: 99
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7968666666666666
# Measured active power lpf [kW]: 803.6756983261588
# Measured reactive power lpf [kVAr]: 493.09374465298055
# Measured apparent power lpf [kVA]: 942.8870924431715
# Discharge
# Discharge power [kW]: 19.223533937926256
#
# Time: 99
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7968666666666666
# Measured active power lpf [kW]: 803.6756983261588
# Measured reactive power lpf [kVAr]: 493.09374465298055
# Measured apparent power lpf [kVA]: 942.8870924431715
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 100
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8967333333333334
# Measured active power lpf [kW]: 803.4790314922824
# Measured reactive power lpf [kVAr]: 493.0699519660898
# Measured apparent power lpf [kVA]: 942.7070231941726
# Discharge
# Discharge power [kW]: 19.17571351709634
#
# Time: 100
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7967333333333333
# Measured active power lpf [kW]: 803.4790314922824
# Measured reactive power lpf [kVAr]: 493.0699519660898
# Measured apparent power lpf [kVA]: 942.7070231941726
# Discharge
# Discharge power [kW]: 19.17571351709634
#
# Time: 100
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7967333333333333
# Measured active power lpf [kW]: 803.4790314922824
# Measured reactive power lpf [kVAr]: 493.0699519660898
# Measured apparent power lpf [kVA]: 942.7070231941726
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 101
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8965972222222223
# Measured active power lpf [kW]: 803.2617037662925
# Measured reactive power lpf [kVAr]: 493.03232271936423
# Measured apparent power lpf [kVA]: 942.5021145777756
# Discharge
# Discharge power [kW]: 19.71692479686245
#
# Time: 101
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7965972222222222
# Measured active power lpf [kW]: 803.2617037662925
# Measured reactive power lpf [kVAr]: 493.03232271936423
# Measured apparent power lpf [kVA]: 942.5021145777756
# Discharge
# Discharge power [kW]: 19.71692479686245
#
# Time: 101
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7965972222222222
# Measured active power lpf [kW]: 803.2617037662925
# Measured reactive power lpf [kVAr]: 493.03232271936423
# Measured apparent power lpf [kVA]: 942.5021145777756
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 102
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8964583333333334
# Measured active power lpf [kW]: 803.0370599010884
# Measured reactive power lpf [kVAr]: 492.99021153130116
# Measured apparent power lpf [kVA]: 942.2886331906276
# Discharge
# Discharge power [kW]: 19.664133395639862
#
# Time: 102
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7964583333333334
# Measured active power lpf [kW]: 803.0370599010884
# Measured reactive power lpf [kVAr]: 492.99021153130116
# Measured apparent power lpf [kVA]: 942.2886331906276
# Discharge
# Discharge power [kW]: 19.664133395639862
#
# Time: 102
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7964583333333334
# Measured active power lpf [kW]: 803.0370599010884
# Measured reactive power lpf [kVAr]: 492.99021153130116
# Measured apparent power lpf [kVA]: 942.2886331906276
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 103
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8963166666666667
# Measured active power lpf [kW]: 802.8386193654018
# Measured reactive power lpf [kVAr]: 492.96753498673957
# Measured apparent power lpf [kVA]: 942.107658017621
# Discharge
# Discharge power [kW]: 20.204986955784264
#
# Time: 103
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7963166666666667
# Measured active power lpf [kW]: 802.8386193654018
# Measured reactive power lpf [kVAr]: 492.96753498673957
# Measured apparent power lpf [kVA]: 942.107658017621
# Discharge
# Discharge power [kW]: 20.204986955784264
#
# Time: 103
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7963166666666667
# Measured active power lpf [kW]: 802.8386193654018
# Measured reactive power lpf [kVAr]: 492.96753498673957
# Measured apparent power lpf [kVA]: 942.107658017621
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 104
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8961722222222223
# Measured active power lpf [kW]: 802.6583184731687
# Measured reactive power lpf [kVAr]: 492.9592844209994
# Measured apparent power lpf [kVA]: 941.9496973358176
# Discharge
# Discharge power [kW]: 20.154645446501917
#
# Time: 104
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7961722222222222
# Measured active power lpf [kW]: 802.6583184731687
# Measured reactive power lpf [kVAr]: 492.9592844209994
# Measured apparent power lpf [kVA]: 941.9496973358176
# Discharge
# Discharge power [kW]: 20.154645446501917
#
# Time: 104
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.7961722222222222
# Measured active power lpf [kW]: 802.6583184731687
# Measured reactive power lpf [kVAr]: 492.9592844209994
# Measured apparent power lpf [kVA]: 941.9496973358176
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 105
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.896025
# Measured active power lpf [kW]: 802.4431744033568
# Measured reactive power lpf [kVAr]: 492.9262001091323
# Measured apparent power lpf [kVA]: 941.7490572867936
# Discharge
# Discharge power [kW]: 20.692025644311457
#
# Time: 105
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.796025
# Measured active power lpf [kW]: 802.4431744033568
# Measured reactive power lpf [kVAr]: 492.9262001091323
# Measured apparent power lpf [kVA]: 941.7490572867936
# Discharge
# Discharge power [kW]: 20.692025644311457
#
# Time: 105
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.796025
# Measured active power lpf [kW]: 802.4431744033568
# Measured reactive power lpf [kVAr]: 492.9262001091323
# Measured apparent power lpf [kVA]: 941.7490572867936
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 106
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.895875
# Measured active power lpf [kW]: 802.1769948283686
# Measured reactive power lpf [kVAr]: 492.8556812012926
# Measured apparent power lpf [kVA]: 941.4853442960558
# Discharge
# Discharge power [kW]: 20.630944826055476
#
# Time: 106
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.795875
# Measured active power lpf [kW]: 802.1769948283686
# Measured reactive power lpf [kVAr]: 492.8556812012926
# Measured apparent power lpf [kVA]: 941.4853442960558
# Discharge
# Discharge power [kW]: 20.630944826055476
#
# Time: 106
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.795875
# Measured active power lpf [kW]: 802.1769948283686
# Measured reactive power lpf [kVAr]: 492.8556812012926
# Measured apparent power lpf [kVA]: 941.4853442960558
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test01
# Time: 107
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.8957222222222222
# Measured active power lpf [kW]: 801.90566596283
# Measured reactive power lpf [kVAr]: 492.78201651020305
# Measured apparent power lpf [kVA]: 941.21560383323
# Discharge
# Discharge power [kW]: 21.160044748542457
#
# Time: 107
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.7957222222222222
# Measured active power lpf [kW]: 801.90566596283
# Measured reactive power lpf [kVAr]: 492.78201651020305
# ...
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.3336113102858
# Measured reactive power lpf [kVAr]: 466.8443057067294
# Measured apparent power lpf [kVA]: 897.335394150182
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1781
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.3336113102858
# Measured reactive power lpf [kVAr]: 466.8443057067294
# Measured apparent power lpf [kVA]: 897.335394150182
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1781
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.3334722222222222
# Measured active power lpf [kW]: 766.3336113102858
# Measured reactive power lpf [kVAr]: 466.8443057067294
# Measured apparent power lpf [kVA]: 897.335394150182
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1782
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.4059998842831
# Measured reactive power lpf [kVAr]: 466.89675933451446
# Measured apparent power lpf [kVA]: 897.424504086945
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1782
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.4059998842831
# Measured reactive power lpf [kVAr]: 466.89675933451446
# Measured apparent power lpf [kVA]: 897.424504086945
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1782
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.33319444444444446
# Measured active power lpf [kW]: 766.4059998842831
# Measured reactive power lpf [kVAr]: 466.89675933451446
# Measured apparent power lpf [kVA]: 897.424504086945
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1783
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.501614106364
# Measured reactive power lpf [kVAr]: 466.9663480768675
# Measured apparent power lpf [kVA]: 897.5423637154446
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1783
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.501614106364
# Measured reactive power lpf [kVAr]: 466.9663480768675
# Measured apparent power lpf [kVA]: 897.5423637154446
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1783
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.3329166666666667
# Measured active power lpf [kW]: 766.501614106364
# Measured reactive power lpf [kVAr]: 466.9663480768675
# Measured apparent power lpf [kVA]: 897.5423637154446
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1784
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.5858765761388
# Measured reactive power lpf [kVAr]: 467.0283163287909
# Measured apparent power lpf [kVA]: 897.6465643107605
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1784
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.5858765761388
# Measured reactive power lpf [kVAr]: 467.0283163287909
# Measured apparent power lpf [kVA]: 897.6465643107605
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1784
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.3326388888888889
# Measured active power lpf [kW]: 766.5858765761388
# Measured reactive power lpf [kVAr]: 467.0283163287909
# Measured apparent power lpf [kVA]: 897.6465643107605
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1785
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.6627087617418
# Measured reactive power lpf [kVAr]: 467.0845804254555
# Measured apparent power lpf [kVA]: 897.741451798409
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1785
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.6627087617418
# Measured reactive power lpf [kVAr]: 467.0845804254555
# Measured apparent power lpf [kVA]: 897.741451798409
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1785
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.3323611111111111
# Measured active power lpf [kW]: 766.6627087617418
# Measured reactive power lpf [kVAr]: 467.0845804254555
# Measured apparent power lpf [kVA]: 897.741451798409
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1786
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.7673291198805
# Measured reactive power lpf [kVAr]: 467.1614438239097
# Measured apparent power lpf [kVA]: 897.87078780929
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1786
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.7673291198805
# Measured reactive power lpf [kVAr]: 467.1614438239097
# Measured apparent power lpf [kVA]: 897.87078780929
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1786
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.33208333333333334
# Measured active power lpf [kW]: 766.7673291198805
# Measured reactive power lpf [kVAr]: 467.1614438239097
# Measured apparent power lpf [kVA]: 897.87078780929
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1787
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.8634515413605
# Measured reactive power lpf [kVAr]: 467.23124216788267
# Measured apparent power lpf [kVA]: 897.9891908969012
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1787
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.8634515413605
# Measured reactive power lpf [kVAr]: 467.23124216788267
# Measured apparent power lpf [kVA]: 897.9891908969012
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1787
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.3318055555555556
# Measured active power lpf [kW]: 766.8634515413605
# Measured reactive power lpf [kVAr]: 467.23124216788267
# Measured apparent power lpf [kVA]: 897.9891908969012
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1788
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.9472637904906
# Measured reactive power lpf [kVAr]: 467.29156964802377
# Measured apparent power lpf [kVA]: 898.0921536790277
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1788
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 766.9472637904906
# Measured reactive power lpf [kVAr]: 467.29156964802377
# Measured apparent power lpf [kVA]: 898.0921536790277
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1788
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.33152777777777775
# Measured active power lpf [kW]: 766.9472637904906
# Measured reactive power lpf [kVAr]: 467.29156964802377
# Measured apparent power lpf [kVA]: 898.0921536790277
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1789
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.0273544192688
# Measured reactive power lpf [kVAr]: 467.34883290531906
# Measured apparent power lpf [kVA]: 898.1903439947383
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1789
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.0273544192688
# Measured reactive power lpf [kVAr]: 467.34883290531906
# Measured apparent power lpf [kVA]: 898.1903439947383
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1789
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.33125
# Measured active power lpf [kW]: 767.0273544192688
# Measured reactive power lpf [kVAr]: 467.34883290531906
# Measured apparent power lpf [kVA]: 898.1903439947383
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1790
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.1135931322914
# Measured reactive power lpf [kVAr]: 467.4105026247875
# Measured apparent power lpf [kVA]: 898.2960774334324
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1790
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.1135931322914
# Measured reactive power lpf [kVAr]: 467.4105026247875
# Measured apparent power lpf [kVA]: 898.2960774334324
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1790
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.3309722222222222
# Measured active power lpf [kW]: 767.1135931322914
# Measured reactive power lpf [kVAr]: 467.4105026247875
# Measured apparent power lpf [kVA]: 898.2960774334324
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1791
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.2271506757827
# Measured reactive power lpf [kVAr]: 467.49220444347117
# Measured apparent power lpf [kVA]: 898.4355636045896
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1791
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.2271506757827
# Measured reactive power lpf [kVAr]: 467.49220444347117
# Measured apparent power lpf [kVA]: 898.4355636045896
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1791
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.33069444444444446
# Measured active power lpf [kW]: 767.2271506757827
# Measured reactive power lpf [kVAr]: 467.49220444347117
# Measured apparent power lpf [kVA]: 898.4355636045896
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1792
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.3452138747832
# Measured reactive power lpf [kVAr]: 467.5777313870781
# Measured apparent power lpf [kVA]: 898.580887925858
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1792
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.3452138747832
# Measured reactive power lpf [kVAr]: 467.5777313870781
# Measured apparent power lpf [kVA]: 898.580887925858
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1792
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.3304166666666667
# Measured active power lpf [kW]: 767.3452138747832
# Measured reactive power lpf [kVAr]: 467.5777313870781
# Measured apparent power lpf [kVA]: 898.580887925858
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1793
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4279914309437
# Measured reactive power lpf [kVAr]: 467.6371231539543
# Measured apparent power lpf [kVA]: 898.6824806256319
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1793
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4279914309437
# Measured reactive power lpf [kVAr]: 467.6371231539543
# Measured apparent power lpf [kVA]: 898.6824806256319
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1793
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.33013888888888887
# Measured active power lpf [kW]: 767.4279914309437
# Measured reactive power lpf [kVAr]: 467.6371231539543
# Measured apparent power lpf [kVA]: 898.6824806256319
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1794
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4756139974186
# Measured reactive power lpf [kVAr]: 467.6703785862171
# Measured apparent power lpf [kVA]: 898.7404525710915
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1794
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4756139974186
# Measured reactive power lpf [kVAr]: 467.6703785862171
# Measured apparent power lpf [kVA]: 898.7404525710915
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1794
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.3298611111111111
# Measured active power lpf [kW]: 767.4756139974186
# Measured reactive power lpf [kVAr]: 467.6703785862171
# Measured apparent power lpf [kVA]: 898.7404525710915
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1795
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4845325821209
# Measured reactive power lpf [kVAr]: 467.6757894424874
# Measured apparent power lpf [kVA]: 898.75088416282
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1795
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4845325821209
# Measured reactive power lpf [kVAr]: 467.6757894424874
# Measured apparent power lpf [kVA]: 898.75088416282
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1795
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.32958333333333334
# Measured active power lpf [kW]: 767.4845325821209
# Measured reactive power lpf [kVAr]: 467.6757894424874
# Measured apparent power lpf [kVA]: 898.75088416282
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1796
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4918364879376
# Measured reactive power lpf [kVAr]: 467.68003821607
# Measured apparent power lpf [kVA]: 898.7593322026826
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1796
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4918364879376
# Measured reactive power lpf [kVAr]: 467.68003821607
# Measured apparent power lpf [kVA]: 898.7593322026826
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1796
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.3293055555555556
# Measured active power lpf [kW]: 767.4918364879376
# Measured reactive power lpf [kVAr]: 467.68003821607
# Measured apparent power lpf [kVA]: 898.7593322026826
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1797
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4618353764696
# Measured reactive power lpf [kVAr]: 467.65646763972916
# Measured apparent power lpf [kVA]: 898.7214476603351
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1797
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.4618353764696
# Measured reactive power lpf [kVAr]: 467.65646763972916
# Measured apparent power lpf [kVA]: 898.7214476603351
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1797
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.32902777777777775
# Measured active power lpf [kW]: 767.4618353764696
# Measured reactive power lpf [kVAr]: 467.65646763972916
# Measured apparent power lpf [kVA]: 898.7214476603351
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1798
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.422398249055
# Measured reactive power lpf [kVAr]: 467.6256333098284
# Measured apparent power lpf [kVA]: 898.6717255275975
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1798
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.422398249055
# Measured reactive power lpf [kVAr]: 467.6256333098284
# Measured apparent power lpf [kVA]: 898.6717255275975
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1798
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.32875
# Measured active power lpf [kW]: 767.422398249055
# Measured reactive power lpf [kVAr]: 467.6256333098284
# Measured apparent power lpf [kVA]: 898.6717255275975
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1799
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.3589507621916
# Measured reactive power lpf [kVAr]: 467.5772277868724
# Measured apparent power lpf [kVA]: 898.5923565553562
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1799
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.3589507621916
# Measured reactive power lpf [kVAr]: 467.5772277868724
# Measured apparent power lpf [kVA]: 898.5923565553562
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1799
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.3284722222222222
# Measured active power lpf [kW]: 767.3589507621916
# Measured reactive power lpf [kVAr]: 467.5772277868724
# Measured apparent power lpf [kVA]: 898.5923565553562
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Time: 1800
# Controller: psc_1
# Device: bsd_1
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.2932982620321
# Measured reactive power lpf [kVAr]: 467.5274305457973
# Measured apparent power lpf [kVA]: 898.5103805024086
# Discharge
# Discharge power [kW]: 25.0
#
# Time: 1800
# Controller: psc_2
# Device: bsd_2
# Battery SOC: 0.2
# Measured active power lpf [kW]: 767.2932982620321
# Measured reactive power lpf [kVAr]: 467.5274305457973
# Measured apparent power lpf [kVA]: 898.5103805024086
# Discharge
# Discharge power [kW]: 30.0
#
# Time: 1800
# Controller: psc_3
# Device: bsd_3
# Battery SOC: 0.32819444444444446
# Measured active power lpf [kW]: 767.2932982620321
# Measured reactive power lpf [kVAr]: 467.5274305457973
# Measured apparent power lpf [kVA]: 898.5103805024086
# Discharge
# Discharge power [kW]: 10.0
#
# test01
# test01
# test02
# Simulation Complete

# %%
env.k.device.devices['bsd_1']['device'].current_capacity
# Out:
# 7200000.0

# %%
from pycigar.utils.logging import logger

Logger = logger()

Logger.log_dict.keys()
# Out:
# dict_keys(['psc_1', 'psc_2', 'psc_3', 'pv_1', 'bsd_1', 'bsd_2', 'bsd_3', 's701a', 's702a', 's703a', 'network'])

# %%
env.k.device.devices['pv_1']['device']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-5d74a0f5cbc3> in <module>
# ----> 1 env.k.device.devices['pv_1']['device'].keys()
#
# AttributeError: 'PVDevice' object has no attribute 'keys'

# %%
# print(Logger.log_dict['bsd_1'].keys())
# print(Logger.log_dict['psc_1'].keys())

# %%
Logger.log_dict['bsd_1'].keys()
# Logger.log_dict['bsd_1']['SOC']

fig1 = plt.figure(figsize = [16, 4])
# plt.plot(Logger.log_dict['psc']['p_target'],'--',label="Target Power")
# plt.plot(Logger.log_dict['psc']['measured_active_power_lpf'],label="Measured Power")
plt.plot(Logger.log_dict['psc_1']['p_target'],'--',label="Target Power")
plt.plot(Logger.log_dict['psc_1']['measured_active_power'],label="Measured Power")
plt.plot(Logger.log_dict['psc_1']['measured_active_power_lpf'],label="Measured Power LPF")
plt.title('Measured Substation Power')
plt.xlabel('Time [s]')
plt.ylabel('Power [kW]')
plt.legend()

fig1.savefig('/home/michael/Desktop/temp/ieee_03_substation_power.png')


fig1 = plt.figure(figsize = [16, 4])
# plt.plot(Logger.log_dict['psc']['p_set'],label="bsd_1_psc p_set")
plt.plot(Logger.log_dict['psc_1']['p_set'],label="psc_1 p_set")
plt.plot(Logger.log_dict['psc_2']['p_set'],label="psc_2 p_set")
plt.plot(Logger.log_dict['psc_3']['p_set'],label="psc_3 p_set")
plt.title('Dist Peak Shaving Controller Setpoints')
plt.xlabel('Time [s]')
plt.ylabel('PSC Setpoints [kW]')
plt.legend()

fig1.savefig('/home/michael/Desktop/temp/ieee_03_setpoint.png')


fig1 = plt.figure(figsize = [16, 4])
# plt.plot(np.array(Logger.log_dict['bsd_1']['p_in'])/1e3,label="bsd_1 p_in")
plt.plot(np.array(Logger.log_dict['bsd_1']['p_out'])/1e3,label="bsd_1 p_out")
# plt.plot(np.array(Logger.log_dict['bsd_2']['p_in'])/1e3,label="bsd_2 p_in")
plt.plot(np.array(Logger.log_dict['bsd_2']['p_out'])/1e3,label="bsd_2 p_out")
# plt.plot(np.array(Logger.log_dict['bsd_3']['p_in'])/1e3,label="bsd_3 p_in")
plt.plot(np.array(Logger.log_dict['bsd_3']['p_out'])/1e3,label="bsd_3 p_out")
# plt.plot(Logger.log_dict['bsd_1_psc']['measured_active_power_lpf'],label="P meas lpf")
plt.title('Battery Power Output')
plt.xlabel('Time [s]')
plt.ylabel('Battery Output [kW]')
plt.legend()

fig1.savefig('/home/michael/Desktop/temp/ieee_03_battery_power.png')


fig1 = plt.figure(figsize = [16, 4])
plt.plot(Logger.log_dict['bsd_1']['SOC'],label="bsd_1 SOC")
plt.plot(Logger.log_dict['bsd_2']['SOC'],label="bsd_2 SOC")
plt.plot(Logger.log_dict['bsd_3']['SOC'],label="bsd_3 SOC")
# plt.plot(Logger.log_dict['bsd_1_psc']['measured_active_power_lpf'],label="P meas lpf")
plt.title('Battery State of Charge')
plt.xlabel('Time [s]')
plt.ylabel('SOC')
plt.legend()

fig1.savefig('/home/michael/Desktop/temp/ieee_03_battery_soc.png')

plt.show()

# fig1.savefig('/home/michael/Desktop/temp/SOC.png')
